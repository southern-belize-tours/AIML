# %% [markdown]
# # 🛠️ Data Science Tools

# %% [markdown]
# This notebook is work done for the [IBM Data Science Tools Course](https://cognitiveclass.ai/courses/data-science-hands-open-source-tools-2)
#
# This work is done by Ian Feekes. You can reach me at **ianfeekes@gmail.com** or my [linkedin](https://linkedin.com/in/ianfeekes)

# %% [markdown]
# ## Intro

# %% [markdown]
# Data is obviously central to data science, focus on extracting, transforming, analyzing, and visualizing it.

# %% [markdown]
# **Open Source Software** is leading the field of data science, but it's Total Cost of Ownership (TCO) can be higher at times due to configuration, customization, and maintenance costs. This is why commercial software also has its place.

# %% [markdown]
# ## Languages of Data Science

# %% [markdown]
# Python, R, and SQL are the primary languages used.
#
# Scaala, Java, C++, julia, js, php, go, ruby, and visual basic also all have their own uses.

# %% [markdown]
# Lots of jobs in data science including:
# * business analyst
# * database engineer
# * data engineer
# * research scientist
# * statistician

# %% [markdown]
# ## 🐍 Python

# %% [markdown]
# About **75%** of listed data science jobs have python in the description.

# %% [markdown]
# ## R

# %% [markdown]
# According to Kaggle data science survey - learning up to 3 languages can increase your salary notably

# %% [markdown]
# R is Free Sotware (not open source)

# %% [markdown]
# Companies that use R include:
# * IBM
# * Google
# * Meta
# * Microsoft
# * Bank of America
# * Uber

# %% [markdown]
# Integrates well with other computer languages, common mathematical operations like matrix multiplication are built-in

# %% [markdown]
# ## 📀 SQL

# %% [markdown]
# Formally pronounced 'S Q L'

# %% [markdown]
# Stands for "Structured Query Language"

# %% [markdown]
# About 20 years older than both Python and R - 1974. Developed by IBM and useful in handling structured data in Relational Databases.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Good because it will help with a lot of jobs involved in data science. Data is accesed directly when performing operations with SQL, speeding up executions for a lot of workflows.

# %% [markdown]
# Many databases available including:
# * MySQL
# * IBM DB2
# * PostgreSQL
# * MariaDB
# * Oracle Database
# * SQL Lite
# * Microsoft SQL Server

# %% [markdown]
# ## Other Languages

# %% [markdown]
# Scala, Java, C++, and Julia are also quite possible (though most conventional languages have some involvement with data science)

# %% [markdown]
# ## Categories of Data Science Tools

# %% [markdown]
# Open source tools are available for various data science tasks.

# %% [markdown]
# **Data Management** is the process of persisting and retrieving data.

# %% [markdown]
# **Data Integration and Transformation** (ETL) is the process of retrieving data from remote data management systems.

# %% [markdown]
# **Data Visualization** is part of both the initial data exploration process, as well as being part of the final deliverable.

# %% [markdown]
# **Model Building** is the process of creating a machine learning or deep learnign model. This model uses the appropriate algorithm trained with a lot of data

# %% [markdown]
# **Model Deployment** makes the machine learning model available to 3rd-party applications.

# %% [markdown]
# **Model Monitoring & Assessment** ensures continuous performance quality checks on the deployed models.

# %% [markdown]
# **Code Asset Management** uses versioning and other collaborative features to facilitate teamwork

# %% [markdown]
# **Data Asset Management** brings the same versioning and collaborative components to data. It also supports replication, backup, and access right management.

# %% [markdown]
# **IDEs** are tools that help data scientists to implement, execute, tests, and deploy their work.

# %% [markdown]
# **Execution Environments** are tools where data preprocessing, model training, and deployment take place.

# %% [markdown]
# ## Open Source Tools for Data Science

# %% [markdown]
# The most widely-used data management tools are **Relational Databases**. This includes:
# * MySQL
# * PostgreSQL

# %% [markdown]
# NoSQL databases are also great for data management e.g.
# * MongoDB
# * Apache CouchDB
# * Apache Cassandra

# %% [markdown]
# Along with File-based tools and cloud file systems:
# * Hadoop
# * Ceph
# * S3

# %% [markdown]
# ETL is often proposed to be changed to ELT. This stresses the fact that data is dumped somewhere and that the Data Engineer or Data Scientist is responsible for this data.

# %% [markdown]
# Tools for ETL include:
# * Apache Airflow
# * Apache Kafka
# * Spark SQL
# * Kubeflow
# * Apache nifi
# * Node-RED (consumes very little resources, can run on a rasberry pi)

# %% [markdown]
# **Data Visualization** tools:
# * Many libraries
# * Hue
# * kibana (EDA web app limited to elastisearch)

# %% [markdown]
# **Model Deployment** - once you've created a machine learning model capable of predicting some key aspects of the future, one should make that model consumable by other developers and turn it into an API. Some of the ways to do this include:
# * Apache PredictionIO (only supports Apache Spark ML models)
# * Seldon (supports nearly every framework like TensorFlow, SparkML, R, Scikit-Learn)
# * MLeap (SparkML)
# * Tensorflow Service (Only tensorflow models, includes tensorflow.js)

# %% [markdown]
# **Model Monitoring and Assessment** tools:
# * ModelDB
# * Prometheus
# * IBM AI Fairnes 360 Open Source Toolkit (good for detecting bias in ML models)
# * IBM Adversarial Robustness 360 Toolbox (good for making a model most robust)
# * IBM Explainability 360 Toolkit - presents similar datapoints within a dataset for manual comparison
