# %% [markdown]
# # ML with Python - Recommender Systems

# %% [markdown]
# **Recommender Systems** capture the pattern of people's behavior and use it to predict what else they might like.

# %% [markdown]
# * Netflix
# * Amazon
# * Linkedin
# * Facebook
# * (Formerly-known-as) Twitter

# %% [markdown]
# *What to buy? Where to eat? What job to apply to?*

# %% [markdown]
# ## Two Main Types

# %% [markdown]
# **Content-Based** vs. **Collaborative-Filtering**

# %% [markdown]
# **Content-Based** systems try to figure out which aspects a user likes about something and shows them more of the same of what they like.

# %% [markdown]
# **Collaborative Filtering** is based on a user saying "*tell me what's popular among my neighbors because I might like it too*". It finds similar groups of users and provides recommendations based on similar tastes within that group.
#
# 🔑 Assumes that a user is interested in the things similar users are interested in

# %% [markdown]
# Two types of recommender systems:
# * Memory Based: uses the entire user-item dataset to generate recommendation. Looks aat things like Correlation, Cosine Similarity, and Euclidean Distance.
# * Model-based: A model of users is developed in an attempt to learn their preferences. ML techniques like regression, clustering, and classification are leveraged.

# %% [markdown]
# ## Content-Based Recommender Systems

# %% [markdown]
# One-hot encode the movie genres first, then multiply the user's rating to get the "*weighted genre matrix*"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We then can normalize the weighted genres to find the user profile
# ![image.png](attachment:image.png)

# %% [markdown]
# You then can multiply the user-profile-matrix by the candidate movie matrix, resulting in the "weighted movites matrix"

# %% [markdown]
# **Problem:** It will only recommend content that is already in the matrix - won't add new categories.

# %% [markdown]
# ## Collaborative-Filtering

# %% [markdown]
# User-based collaborative filtering, item-based collaborative filtering.
