# %% [markdown]
# # Bank Churn Binary Classification

# %% [markdown]
# This notebook is created by **Ian Feekes** as part of the kaggle competition playground series season 4, episode 1

# %% [markdown]
# The goal of this dataset competition is to predict whether the customer exits their account (i.e. it "Churns").
#
# The evaluation metric is the area under the ROC curve. The ROC curve is an acronym for the "Receiver Operating Characteristic" which is used for evaluating the performance of binary classification models. It is the **true positive rate** against the **false positive rate**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Other Notebook Observations

# %% [markdown]
# Feature engineering columns:
#
# Categorical:
#     * **IsSenior** column which is true if one is above the age of 60. It's hard to imagine this being particularly valuable as it should be fairly imbalanced.
#     * **IsActive_by_CreditCard** is whether someone is both active and has a credit card
#     * **Products Per Tenure** is tenure over the number of products
#     * **Age Category** is the ages binned by 20
#     * **Customer_Sur_Geo_Gend** is the customer ID + surname + geography + gender
#
# Numerical: Just the default (Age, creditScore, balance, estimated salary, products per tenure)

# %% [markdown]
# #### Scale position weight hyperparameter estimate

# %%
# from collections import Counter

# counter = Counter(y)
# pos_estimate = counter[0] / counter[1]
# print('Estimate: %.3f' % pos_estimate)

# %% [markdown]
# From there you can do a training split to stratify based on the counter e.g.
#
# ```X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42, test_size=0.2, stratify=y)```

# %% [markdown]
# Then when you create an XGB Classifier, you add the ```pos_estimate``` as a parameter for the ```scale_pos_weight``` e.g.
#
# ```clf = XGBClassifier(scale_pos_weight=pos_estimate, n_estimators = n, enable_categorical=True)```

# %% [markdown]
# ## Initial Configuration

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

from collections import Counter

# %% [markdown]
# ### Global Variables

# %%
target = 'Exited'

# %% [markdown]
# ### Helper Functions

# %%
"""Helper function to show a simple pie chart of a categorical variable for distribution analysis"""
def do_pie(df, col, title=""):
    if col not in df.columns:
        print("Error, column specified is not in the dataframe's columns")
        return
    val_counts = df[col].value_counts()
    plt.pie(val_counts, labels=val_counts.keys(), autopct='%1.1f%%')
    if title == "":
        title = "Distribution of " + col
    plt.title(title)
    plt.show()

"""Helper function to plot side-by-side pie charts for the different survival rates for differing values in a column
  NOTE: the otherCol needs to be a boolean column with value counts else this function will likely break"""
def plot_target_representation(df, col, otherCol=target):
    grouped = df.groupby([col, otherCol]).size().unstack().fillna(0)
    value_counts = df[col].value_counts()
    target_labels = df[otherCol].value_counts().keys().sort_values()
    fig, axes = plt.subplots(1, len(value_counts.keys()), figsize=(16,6))
    for idx, key in enumerate(value_counts.keys()):
        axes[idx].pie(grouped.loc[key], labels=target_labels, autopct='%1.1f%%', startangle=90)
        axes[idx].set_title(col + " " + str(key))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Load the Dataframe ⬇️

# %%
df = pd.read_csv('./train.csv')
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## EDA

# %% [markdown]
# The dataframe has 14 columns.
# * It looks like the ```id``` is simply the index and will be of no value in analytics.
# * ```CustomerId``` may have more meaning in analytics.
# * ```Surname``` is a string with plenty of names. In real life applications, this would be considered sensitive data.
# * ```CreditScore``` is an integer representing the customer's credit scores. It may be useful to find out the actual bracketing system that most banks use for credit scores.
# * ```Geography``` is a string that looks like it has the country of the customer in it. This would also be considered sensitive data in real applications. This variable will likely be valuable and need some encoding.
# * ```Gender``` is just **Male** or **Female** as usual.
# * ```Age``` is a float interestingly enough.
# * ```Tenure``` is an integer
# * ```Balance``` is a float
# * ```NumOfProducts``` is a float. It may be more of a categorical variable with some outlier testing required.
# * ```Has CrCard``` is likely a boolean denoting whether a user has a credit card.
# * ```IsActiveMember``` is likely a boolean denoting whether they have been 'active' on the account.
# * ```EstimatedSalary``` is a float for their estimated salary
# * ```Exited``` is the target variable for bank churn.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %% [markdown]
# There are 165,034 entries in the initial training dataframe.

# %%
df.shape
# Out:
# (165034, 14)

# %%
df.describe()
# Out:
#                 id    CustomerId    CreditScore            Age         Tenure  \
# count  165034.0000  1.650340e+05  165034.000000  165034.000000  165034.000000
# mean    82516.5000  1.569201e+07     656.454373      38.125888       5.020353
# std     47641.3565  7.139782e+04      80.103340       8.867205       2.806159
# min         0.0000  1.556570e+07     350.000000      18.000000       0.000000
# 25%     41258.2500  1.563314e+07     597.000000      32.000000       3.000000
# 50%     82516.5000  1.569017e+07     659.000000      37.000000       5.000000
# 75%    123774.7500  1.575682e+07     710.000000      42.000000       7.000000
# max    165033.0000  1.581569e+07     850.000000      92.000000      10.000000
#
#              Balance  NumOfProducts      HasCrCard  IsActiveMember  \
# count  165034.000000  165034.000000  165034.000000   165034.000000
# mean    55478.086689       1.554455       0.753954        0.497770
# std     62817.663278       0.547154       0.430707        0.499997
# min         0.000000       1.000000       0.000000        0.000000
# 25%         0.000000       1.000000       1.000000        0.000000
# 50%         0.000000       2.000000       1.000000        0.000000
# 75%    119939.517500       2.000000       1.000000        1.000000
# max    250898.090000       4.000000       1.000000        1.000000
#
#        EstimatedSalary         Exited
# count    165034.000000  165034.000000
# mean     112574.822734       0.211599
# std       50292.865585       0.408443
# min          11.580000       0.000000
# 25%       74637.570000       0.000000
# 50%      117948.000000       0.000000
# 75%      155152.467500       0.000000
# max      199992.480000       1.000000

# %% [markdown]
# There are no missing values on first impression. Granted, it is still possible there are 'valued' missing values (e.g. categorical variables with 'other' or numerical variables that don't make sense)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Indeed the id is just an index and is likely pretty meaningless

# %%
df['id'].value_counts().sum() == df.shape[0]
# Out:
# True

# %% [markdown]
# There are more men than women account holders

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      93150
# Female    71884
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 37.00    9255
# 38.00    9246
# 35.00    9118
# 34.00    8625
# 36.00    8556
#          ...
# 84.00       4
# 83.00       3
# 85.00       3
# 36.44       1
# 32.34       1
# Name: count, Length: 71, dtype: int64

# %% [markdown]
# #### 🎯 Target Variable

# %% [markdown]
# There is what would be considered by Google to be a **Mild Imbalance** of 21.2% for the target variable.

# %%
do_pie(df, target)

# %% [markdown]
# There are only ```0``` and ```1``` values for whether a customer exited. This variable is already pre-encoded and won't need any cleaning.

# %%
df[target].value_counts()
# Out:
# Exited
# 0    130113
# 1     34921
# Name: count, dtype: int64

# %% [markdown]
# #### 🆔 Customer ID

# %% [markdown]
# Looking at the value counts, we can see there are **23221** unique values for the customer id. This may be an issue since this might mean there are some duplicates in the data. A few individual rows will need to be examined to determine whether they are pure duplicates or if there are differences - but we note there is no timestamp, so it isn't useful yet to treat the data as time-series.

# %%
df['CustomerId'].value_counts()
# Out:
# CustomerId
# 15682355    121
# 15570194     99
# 15585835     98
# 15595588     91
# 15648067     90
#            ...
# 15635203      1
# 15806982      1
# 15691104      1
# 15624936      1
# 15815050      1
# Name: count, Length: 23221, dtype: int64

# %% [markdown]
# It doesn't look like there are any pure duplicates in the dataframe.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Looking at the ```CustomerId``` of a specific value (e.g. **15682355**) we see the entries are completely different. There are multiple values of the ID at a given number with the same surname **Hsueh** with completely different characteristics (gender, age, credit score etc.).
#
# It is possible that we don't fully understand what the CustomerId acutally means.

# %%
df[df['CustomerId'] == 15682355]
# Out:
#             id  CustomerId      Surname  CreditScore Geography  Gender   Age  \
# 273        273    15682355        Hsueh          727   Germany    Male  35.0
# 2565      2565    15682355         Tien          744    France    Male  37.0
# 5063      5063    15682355          Niu          790     Spain    Male  44.0
# 11942    11942    15682355        Hsueh          616    France  Female  43.0
# 13009    13009    15682355        Manna          652     Spain  Female  33.0
# ...        ...         ...          ...          ...       ...     ...   ...
# 159573  159573    15682355  Onwuatuegwu          679    France  Female  39.0
# 159690  159690    15682355        Pinto          629   Germany  Female  34.0
# 159923  159923    15682355    O'Donnell          710    France  Female  35.0
# 160819  160819    15682355           L?          773     Spain    Male  38.0
# 164134  164134    15682355         Hsia          656    France    Male  47.0
#
#         Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 273          9  140966.55              1        1.0             1.0
# 2565         6       0.00              2        1.0             1.0
# 5063         1  128100.75              1        1.0             0.0
# 11942        9   95167.82              2        0.0             1.0
# 13009        7       0.00              2        1.0             1.0
# ...        ...        ...            ...        ...             ...
# 159573       6       0.00              2        1.0             0.0
# 159690       2  140510.34              2        1.0             0.0
# 159923       7       0.00              2        1.0             1.0
# 160819       6  138597.54              1        1.0             0.0
# 164134       5       0.00              2        1.0             0.0
#
#         EstimatedSalary  Exited
# 273           179227.21       0
# 2565          137944.16       0
# 5063          164517.96       1
# 11942         132741.56       0
# 13009         112333.22       0
# ...                 ...     ...
# 159573        123977.86       0
# 159690        143681.75       0
# 159923        147055.87       0
# 160819         52314.71       0
# 164134        170514.21       0
#
# [121 rows x 14 columns]

# %% [markdown]
# #### Surname

# %% [markdown]
# There are 2797 unique surnames. They may not be individually useful but perhaps can be used to help infer things.

# %%
df['Surname'].value_counts()
# Out:
# Surname
# Hsia         2456
# T'ien        2282
# Hs?          1611
# Kao          1577
# Maclean      1577
#              ...
# Samaniego       1
# Lawley          1
# Bonwick         1
# Tennant         1
# Elkins          1
# Name: count, Length: 2797, dtype: int64

# %% [markdown]
# #### 💳 CreditScore

# %% [markdown]
# From the boxplot of credit score values, we are able to see that there is a mean in the mid-high 600's. The max values are at 850, and the minimal values are around 350, with most people exibiting a wide range between 450 and 850. There is a slight left skew, but very-slight.

# %%
plt.boxplot(df['CreditScore'])
plt.title("Boxplot of Credit Score")
plt.show()

# %% [markdown]
# There are some outliers for the credit score and there is definetely a bit of a left skew (but not too bad)

# %%
plt.hist(df['CreditScore'], bins=50)
plt.title("Histogram of Credit Score")
plt.show()

# %% [markdown]
# #### 🌎 Geography

# %% [markdown]
# Most of the users are from **France** with two mild imbalances for **Spain** and **Germany**.

# %%
do_pie(df, 'Geography')

# %% [markdown]
# Looking at the distribution of those who did and did not churn, it is apparent that many more Germans will exit their accounts as opposed to not. Spanish exibit a close balance, and the French tend to not move their accounts around as much.

# %%
plot_target_representation(df, target, 'Geography')

# %%
df.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# #### ⚧ Gender

# %% [markdown]
# There are slightly more men than there are women, but it is not a particularly noteworthy imbalance.

# %%
do_pie(df, 'Gender')

# %% [markdown]
# Women tend to be more likely to exit, men less likely than the general population

# %%
plot_target_representation(df, 'Gender')

# %%
df.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# #### Age

# %% [markdown]
# The plot looks a little wonky because age isn't given integer values, but it's actually quite a nice little normal distribution with the typical slight right skew (given that infants can't have bank accounts, and that some people live for very long times)

# %%
plt.hist(df['Age'], bins=100)
plt.title("Histogram of Age")
plt.show()

# %% [markdown]
# The boxplot for age seems very typical of EDA for machine learning. It might need some log transformation or outlier grouping.

# %%
plt.boxplot(df['Age'])
plt.title("Boxplot of Age")
plt.show()

# %% [markdown]
# #### Tenure

# %% [markdown]
# For a variable with 10 different categories, **Tenure** is actually quite well-balanced. Fewer individuals have a **Tenure** value of ```0``` or ```10```

# %%
do_pie(df, 'Tenure')

# %% [markdown]
# The only particularly interesting patterns for the target representation's correlation with tenure are values of ```7```, which exhibits some negative correlation, and ```0``` which exhibits notably high correlation.

# %%
plot_target_representation(df, 'Tenure')

# %% [markdown]
# #### Balance

# %% [markdown]
# Looks like the majority of account-holders have next-to-nothing. This variable will likely need to be binned.

# %%
plt.boxplot(df['Balance'])
plt.title("Boxplot of Balance")
plt.show()

# %% [markdown]
# We can see that the vast majority of users have almost ```nothing``` in their account. The rest exhibit a relatively normal distribution between ```50000``` and ```20000``` worth of account holdings.

# %%
plt.hist(df['Balance'], bins=50)
plt.title("Histogram of Balances")
plt.show()

# %% [markdown]
# #### NumOfProducts

# %% [markdown]
# There is an **extreme** imbalance in ```3``` products, and a **severe** imbalance in ```4``` products. This variable should be examined to see if these can be aggregated as part of 2 products or something.

# %%
do_pie(df, 'NumOfProducts')

# %% [markdown]
# While the number of products values with ```3``` are a moderate-to-extreme minority, they still represent 2894 data points which is substantial enough to be worth considering. There are only **474** data points with ```4``` products, so these are statistically fairly insignificant.

# %%
df['NumOfProducts'].value_counts()
# Out:
# NumOfProducts
# 2    84291
# 1    77374
# 3     2894
# 4      475
# Name: count, dtype: int64

# %% [markdown]
# We see some notable trends for the number of products.
# * Those with ```1``` product have notably statistically higher percentages of exiting
# * Those with ```2``` products have notably statistically lower percentages of exiting (with 6% compared to the 20.5% of the general population).
# * Those with ```3``` (and with ```4```) products have extremely high statistical percentages correlating to exiting.

# %%
plot_target_representation(df, 'NumOfProducts')

# %% [markdown]
# #### Has CR Card

# %% [markdown]
# Most users have a credit card, only 25% do not.

# %%
do_pie(df, 'HasCrCard')

# %% [markdown]
# There doesn't seem to be a particularly strong representation between exiting and those who do and do not have a credit card.
# Those who do have a credit card seem to have a very slightly lower percentage for exiting and those who do not have a credit card have a very slightly lower percentage for exiting.

# %%
plot_target_representation(df, 'HasCrCard')

# %% [markdown]
# #### Is Active Member

# %% [markdown]
# There is a really nice split of those who are active members and those who are not.

# %%
do_pie(df, 'IsActiveMember')

# %% [markdown]
# The level of activity exhibited by members seems to have a very notable correlation with the churn rate.
#
# * ```Active Members``` exhibit a 12.5% churn rate compared to the general population's 20.5%
# * ```Non-Active Members``` exhibit a 29.7% churn rate, nearly 10% higher than the general population.

# %%
plot_target_representation(df, 'IsActiveMember')

# %% [markdown]
# #### Estimated Salary

# %% [markdown]
# Most people make around ```120k``` with a slight right skew on the curve.

# %%
plt.boxplot(df['EstimatedSalary'])
plt.title("Boxplot of Estimated Salary")
plt.show()

# %% [markdown]
# The curve for estimated salary is a bit ugly, with a few notable clusters around thresholds (50-60, 75-90, 120-140, ...). 2500 data points make nothing.

# %%
plt.hist(df['EstimatedSalary'], bins=50)
plt.title("Histogram of Estimated Salary")
plt.show()

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Below, we define the categorical variables for encoding. Binary categorical variables will likely stay untouched.
# We declare the numerical variables for scaling.
# We declare the variables we are not interested in keeping for model training.

# %%
categorical_variables = ['IsActiveMember', 'HasCrCard', 'Gender', 'NumOfProducts', 'Tenure', 'Geography']
numerical_variables = ['EstimatedSalary', 'Age', 'Balance', 'CreditScore', ]
remove = ['id', 'CustomerId', 'Surname']

categorical_variables.remove('Tenure')
numerical_variables.append('Tenure')

categorical_variables.remove('NumOfProducts')
numerical_variables.append('NumOfProducts')

# %% [markdown]
# ### Final Analysis

# %% [markdown]
# While this is more of an EDA measure (not data cleaning), the below cell still gives us some interesting information.
# * It actually looks like a few of the bins for estimated salary see slightly higher exit rates in proportion to some of the smaller salaries.
# * A lot more of the older folks tend to exit relative to younger.
# * Those with ```some``` balance tended to see higher exit rates than those with ```no``` balance.
# * it is difficult to make anything out of credit score.

# %%
_, axes = plt.subplots(nrows= 2, ncols=2, figsize=(16,10))
for feat, ax in zip(numerical_variables, axes.ravel()):
    if df[feat].dtype == 'object':
        sns.countplot(data=df, x=feat, ax=ax, hue=target)
    else:
        sns.histplot(data=df, x=feat, bins=50, ax=ax, hue=target)
plt.show()

# %% [markdown]
# Likewise, while this is also more of eda, running the countplots of the categorical variables proves useful.
# * Active members have a lower exit rate than non-active members
# * Women tend to have higher exit rates than men
# * Those with ```1```, ```3```, or ```4``` products tend to have notably higher exit rates than those with ```2``` products
# * ```Germany``` has notably higher exit rates. ```France``` has notably lower exit rates.

# %%
_, axes = plt.subplots(nrows= 2, ncols=3, figsize=(16,10))
for feat, ax in zip(categorical_variables, axes.ravel()):
    sns.countplot(data=df, x=feat, ax=ax, hue=target)
plt.show()

# %%
df_clean = df.copy()

# %% [markdown]
# ### Feaure Engineering

# %%
df_clean['isSenior'] = df['Age'].apply(lambda x: 1 if x >=60 else 0)

# %%
df_clean['activeByCard'] = df_clean['HasCrCard'] * df_clean['IsActiveMember']

# %%
df_clean['productsPerTenure'] = df_clean['Tenure'] / df_clean['NumOfProducts']

# %%
df_clean['ageCat'] = np.round(df_clean.Age/20).astype('int').astype('category')

# %%
# df_clean['isSenior'] = df['Age'].apply(lambda x: 1 if x >=60 else 0)
# df_clean['activeByCard'] = df_clean['HasCrCard'] * df_clean['IsActiveMember']
# df_clean['productsPerTenure'] = df_clean['Tenure'] / df_clean['NumOfProducts']
# df_clean['ageCat'] = np.round(df_clean.Age/20).astype('int').astype('category')

# %% [markdown]
# ### Actual Cleaning

# %%
df_clean = df_clean.drop(remove, axis=1)
df_clean.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'isSenior', 'activeByCard', 'productsPerTenure', 'ageCat'],
#       dtype='object')

# %%
# scaler = StandardScaler()
scaler = MinMaxScaler()

df_clean[numerical_variables] = scaler.fit_transform(df_clean[numerical_variables])
df_clean.describe()
# Out:
#          CreditScore            Age         Tenure        Balance  \
# count  165034.000000  165034.000000  165034.000000  165034.000000
# mean        0.612909       0.271971       0.502035       0.221118
# std         0.160207       0.119827       0.280616       0.250371
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.494000       0.189189       0.300000       0.000000
# 50%         0.618000       0.256757       0.500000       0.000000
# 75%         0.720000       0.324324       0.700000       0.478041
# max         1.000000       1.000000       1.000000       1.000000
#
#        NumOfProducts      HasCrCard  IsActiveMember  EstimatedSalary  \
# count  165034.000000  165034.000000   165034.000000    165034.000000
# mean        0.184818       0.753954        0.497770         0.562870
# std         0.182385       0.430707        0.499997         0.251488
# min         0.000000       0.000000        0.000000         0.000000
# 25%         0.000000       1.000000        0.000000         0.373166
# 50%         0.333333       1.000000        0.000000         0.589738
# 75%         0.333333       1.000000        1.000000         0.775779
# max         1.000000       1.000000        1.000000         1.000000
#
#               Exited       isSenior   activeByCard  productsPerTenure
# count  165034.000000  165034.000000  165034.000000      165034.000000
# mean        0.211599       0.028733       0.370766           3.662846
# std         0.408443       0.167057       0.483011           2.517497
# min         0.000000       0.000000       0.000000           0.000000
# 25%         0.000000       0.000000       0.000000           1.666667
# 50%         0.000000       0.000000       0.000000           3.000000
# 75%         0.000000       0.000000       1.000000           5.000000
# max         1.000000       1.000000       1.000000          10.000000

# %%
# Helper function to encode a variable
def encode(df, cols):
    new_categories = []
    for col in cols:
        if col in df.columns:
            one_hot_encoded = pd.get_dummies(df[col], prefix=col)
            for new_col in one_hot_encoded.columns:
                new_categories.append(new_col)
            df = pd.concat([df, one_hot_encoded], axis=1)
            if not (col == target):
                df = df.drop([col], axis = 1)
    return df, new_categories

# %%
df_clean, _ = encode(df_clean, categorical_variables)
df_clean.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'EstimatedSalary', 'Exited', 'isSenior', 'activeByCard',
#        'productsPerTenure', 'ageCat', 'IsActiveMember_0.0',
#        'IsActiveMember_1.0', 'HasCrCard_0.0', 'HasCrCard_1.0', 'Gender_Female',
#        'Gender_Male', 'Geography_France', 'Geography_Germany',
#        'Geography_Spain'],
#       dtype='object')

# %% [markdown]
# The **balance** has a strong correlation with many variables. This includes a strong negative correlation with number of products, a slight positive correlation with exiting, a slight negative correlation with geography from france, a very high positive correlation with germany, and a very slight negative correlation with being from spain.
#     - It is likely that combining some feature variable that looks at number of products combined with geography could be useful.
#
# * **Age**, which is one of the most valuable features, has very little correlation with any of the other features aside from the target variable.
# * **Tenure** applies similarly with the observations seen in age.
# * **Estimated Salary** has the same observations.
#
# * **Has Credit Card** doesn't correlate very highly with other variables as well, but it is low on the significance score for baseline machine learning models.
#
# * **Credit Score** doesn't seemingly have a very high correlation with any other variables even though we know it is one of the most important variables in predicting bank churn.

# %%
sns.set(rc={'figure.figsize':(10,10)})

corr = df_clean.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(100, 7, s = 75, l = 40, n = 20, center = 'light', as_cmap = True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, square=True, linewidths=.5, cbar_kws={'shrink':.5}, annot=True, fmt='.1f')
plt.show()

# %%
features = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary',
            

       'ageCat',
       
       # isSenior saw worse performance on single model validation and in 5 fold cross validation
       # 'isSenior',

       # 'IsActiveMember_0.0',
       'IsActiveMember_1.0', 
       # 'HasCrCard_0.0',
       'HasCrCard_1.0',
       'activeByCard',

       'Gender_Female',
       
       # 'Gender_Male',

       'NumOfProducts',
       # 'NumOfProducts_1', 'NumOfProducts_2', 'NumOfProducts_3', 'NumOfProducts_4',

       'productsPerTenure',

       'Tenure',
       # 'Tenure_0', 'Tenure_1', 'Tenure_2', 'Tenure_3', 'Tenure_4', 'Tenure_5', 'Tenure_6', 'Tenure_7', 'Tenure_8', 'Tenure_9', 'Tenure_10',
       
       'Geography_France',
       'Geography_Germany', 'Geography_Spain']

counter = Counter(df_clean[target])
pos_estimate = counter[0] / counter[1]
print('Pos Estimate: %.3f' % pos_estimate)

X_train, X_test, y_train, y_test = train_test_split(df_clean[features], df_clean[target], test_size=0.2, random_state=42, stratify=df_clean[target])
# X_train = df_clean[features]
# y_train = df_clean[target]
# Out:
# Pos Estimate: 3.726

# %% [markdown]
# ## 🤖 Machine Learning

# %% [markdown]
# ### 🌳 Decision Tree Classifier

# %%
classifier = DecisionTreeClassifier(max_depth=50)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=50)

# %%
# Predict using the test set
y_pred = classifier.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.80
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87     26023
#            1       0.52      0.54      0.53      6984
#
#     accuracy                           0.80     33007
#    macro avg       0.70      0.70      0.70     33007
# weighted avg       0.80      0.80      0.80     33007

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### Initialize and Fit the Model

# %%
xgb_params =  {'colsample_bytree': 0.8,
               'learning_rate': 0.1,
               'max_depth': 4,
               'scale_pos_weight': pos_estimate,
               'eval_metric': "auc",
               'n_estimators': 50,
               'early_stopping_rounds': 400,
               'enable_categorical': True,
            #    'tree_method': 'hist',
               'subsample': 0.9}

xgb_model = XGBClassifier(**xgb_params )
# xgb_model = XGBClassifier()

xgb_model.fit(X_train, y_train, verbose=50, eval_set=[(X_test, y_test)] )
# xgb_model.fit(X_train, y_train, verbose=50 )
# Out:
# [0]	validation_0-auc:0.86106
# [49]	validation_0-auc:0.88841
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=400,
#               enable_categorical=True, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# #### Hyperparameter Tuning

# %% [markdown]
# Best parameters found:  {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200, 'subsample': 1.0}
# Best score found:  0.8653078536965925
#
# Best parameters found:  {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 400, 'subsample': 0.9}
# Best score found:  0.888987004778651
#
# .88900

# %%
param_grid = {
    # 'n_estimators': [50, 75, 100, 400, 600, 700, 800, 900, 1000],
    'n_estimators': [400],
    # 'learning_rate': [0.1, 0.2, 0.3],
    # 'learning_rate': [0.1],
    # 'max_depth': [2, 3, 4, 5, 6, 8, 10, 12],
    'max_depth': [4],
    # 'subsample': [0.8, 0.9, 1.0],
    # 'colsample_bytree': [0.8, 0.9, 1.0],
}

perform_xgb_tuning = True

if perform_xgb_tuning == True:
    model = XGBClassifier(**xgb_params)
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2, scoring="roc_auc")
    grid_search.fit(X_train, y_train, eval_set=[(X_test, y_test)])

    print("Best parameters found: ", grid_search.best_params_)
    print("Best score found: ", grid_search.best_score_)
else:
    print("Hyperparameter tuning skipped.")
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [0]	validation_0-auc:0.86160
# [0]	validation_0-auc:0.86160
# [0]	validation_0-auc:0.86111
# [1]	validation_0-auc:0.85955
# [0]	validation_0-auc:0.86141
# [1]	validation_0-auc:0.85998
# [1]	validation_0-auc:0.86008
# [2]	validation_0-auc:0.86963
# [1]	validation_0-auc:0.85890
# [2]	validation_0-auc:0.86797
# [3]	validation_0-auc:0.86934
# [2]	validation_0-auc:0.86766
# [2]	validation_0-auc:0.86916
# [3]	validation_0-auc:0.86859
# [0]	validation_0-auc:0.86126
# [4]	validation_0-auc:0.87221
# [3]	validation_0-auc:0.86963
# [4]	validation_0-auc:0.87263
# [5]	validation_0-auc:0.87133
# [3]	validation_0-auc:0.86809
# [1]	validation_0-auc:0.85895
# [5]	validation_0-auc:0.87177
# [6]	validation_0-auc:0.87365
# [4]	validation_0-auc:0.87269
# [6]	validation_0-auc:0.87370
# [2]	validation_0-auc:0.86770
# [4]	validation_0-auc:0.87250
# [7]	validation_0-auc:0.87842
# [5]	validation_0-auc:0.87163
# [7]	validation_0-auc:0.87853
# [6]	validation_0-auc:0.87404
# [8]	validation_0-auc:0.88034
# [5]	validation_0-auc:0.87223
# [3]	validation_0-auc:0.86884
# [8]	validation_0-auc:0.88072
# [9]	validation_0-auc:0.88110
# [9]	validation_0-auc:0.88161
# [7]	validation_0-auc:0.87833
# [6]	validation_0-auc:0.87400
# [10]	validation_0-auc:0.88107
# [10]	validation_0-auc:0.88227
# [11]	validation_0-auc:0.88135
# [7]	validation_0-auc:0.87873
# [11]	validation_0-auc:0.88252
# [12]	validation_0-auc:0.88239
# [8]	validation_0-auc:0.88048
# [8]	validation_0-auc:0.88085
# [4]	validation_0-auc:0.87251
# [9]	validation_0-auc:0.88171
# [13]	validation_0-auc:0.88219
# [12]	validation_0-auc:0.88319
# [9]	validation_0-auc:0.88174
# [10]	validation_0-auc:0.88209
# [14]	validation_0-auc:0.88218
# [13]	validation_0-auc:0.88299
# [10]	validation_0-auc:0.88217
# [15]	validation_0-auc:0.88205
# [11]	validation_0-auc:0.88205
# [5]	validation_0-auc:0.87124
# [16]	validation_0-auc:0.88207
# [11]	validation_0-auc:0.88217
# [14]	validation_0-auc:0.88314
# [12]	validation_0-auc:0.88316
# [17]	validation_0-auc:0.88260
# [12]	validation_0-auc:0.88295
# [13]	validation_0-auc:0.88305
# [18]	validation_0-auc:0.88249
# [15]	validation_0-auc:0.88319
# [6]	validation_0-auc:0.87377
# [14]	validation_0-auc:0.88305
# [19]	validation_0-auc:0.88334
# [13]	validation_0-auc:0.88275
# [16]	validation_0-auc:0.88321
# [20]	validation_0-auc:0.88399
# [7]	validation_0-auc:0.87848
# [15]	validation_0-auc:0.88293
# [14]	validation_0-auc:0.88291
# [21]	validation_0-auc:0.88430
# [17]	validation_0-auc:0.88357
# [15]	validation_0-auc:0.88293
# [8]	validation_0-auc:0.88067
# [22]	validation_0-auc:0.88482
# [18]	validation_0-auc:0.88351
# [16]	validation_0-auc:0.88304
# [16]	validation_0-auc:0.88288
# [19]	validation_0-auc:0.88425
# [23]	validation_0-auc:0.88501
# [17]	validation_0-auc:0.88343
# [17]	validation_0-auc:0.88345
# [20]	validation_0-auc:0.88463
# [24]	validation_0-auc:0.88538
# [9]	validation_0-auc:0.88156
# [18]	validation_0-auc:0.88332
# [18]	validation_0-auc:0.88333
# [21]	validation_0-auc:0.88492
# [10]	validation_0-auc:0.88205
# [19]	validation_0-auc:0.88416
# [22]	validation_0-auc:0.88533
# [11]	validation_0-auc:0.88161
# [19]	validation_0-auc:0.88429
# [25]	validation_0-auc:0.88571
# [23]	validation_0-auc:0.88555
# [20]	validation_0-auc:0.88465[20]	validation_0-auc:0.88463
#
# [26]	validation_0-auc:0.88590
# [12]	validation_0-auc:0.88292
# [24]	validation_0-auc:0.88583
# [21]	validation_0-auc:0.88477
# [27]	validation_0-auc:0.88603
# [21]	validation_0-auc:0.88486
# [13]	validation_0-auc:0.88283
# [22]	validation_0-auc:0.88520
# [22]	validation_0-auc:0.88518
# [28]	validation_0-auc:0.88618
# [23]	validation_0-auc:0.88550
# [14]	validation_0-auc:0.88283
# [23]	validation_0-auc:0.88536
# [29]	validation_0-auc:0.88633
# [25]	validation_0-auc:0.88606
# [15]	validation_0-auc:0.88285
# [24]	validation_0-auc:0.88587
# [24]	validation_0-auc:0.88575
# [30]	validation_0-auc:0.88633
# [16]	validation_0-auc:0.88305
# [25]	validation_0-auc:0.88611
# [26]	validation_0-auc:0.88619
# [25]	validation_0-auc:0.88594
# [31]	validation_0-auc:0.88643
# [26]	validation_0-auc:0.88620
# [17]	validation_0-auc:0.88335
# [32]	validation_0-auc:0.88654
# [18]	validation_0-auc:0.88324
# [26]	validation_0-auc:0.88602
# [27]	validation_0-auc:0.88625
# [33]	validation_0-auc:0.88667
# [19]	validation_0-auc:0.88415
# [27]	validation_0-auc:0.88606
# [28]	validation_0-auc:0.88646
# [27]	validation_0-auc:0.88629
# [34]	validation_0-auc:0.88695
# [20]	validation_0-auc:0.88451
# [29]	validation_0-auc:0.88680
# [28]	validation_0-auc:0.88621
# [35]	validation_0-auc:0.88715
# [28]	validation_0-auc:0.88642
# [21]	validation_0-auc:0.88468
# [30]	validation_0-auc:0.88683
# [29]	validation_0-auc:0.88659
# [36]	validation_0-auc:0.88721
# [22]	validation_0-auc:0.88497
# [29]	validation_0-auc:0.88668
# [31]	validation_0-auc:0.88699
# [30]	validation_0-auc:0.88661
# [37]	validation_0-auc:0.88723
# [23]	validation_0-auc:0.88517
# [32]	validation_0-auc:0.88717
# [30]	validation_0-auc:0.88677
# [31]	validation_0-auc:0.88690
# [38]	validation_0-auc:0.88730
# [24]	validation_0-auc:0.88560
# [33]	validation_0-auc:0.88734
# [31]	validation_0-auc:0.88694
# [32]	validation_0-auc:0.88696
# [39]	validation_0-auc:0.88745
# [34]	validation_0-auc:0.88750
# [25]	validation_0-auc:0.88578
# [32]	validation_0-auc:0.88705
# [33]	validation_0-auc:0.88709
# [40]	validation_0-auc:0.88761
# [35]	validation_0-auc:0.88759
# [26]	validation_0-auc:0.88577
# [33]	validation_0-auc:0.88716
# [41]	validation_0-auc:0.88772
# [34]	validation_0-auc:0.88729
# [36]	validation_0-auc:0.88764
# [27]	validation_0-auc:0.88583
# [34]	validation_0-auc:0.88738
# [37]	validation_0-auc:0.88766
# [35]	validation_0-auc:0.88739
# [42]	validation_0-auc:0.88775
# [28]	validation_0-auc:0.88608
# [35]	validation_0-auc:0.88747
# [36]	validation_0-auc:0.88750
# [38]	validation_0-auc:0.88771
# [43]	validation_0-auc:0.88785
# [29]	validation_0-auc:0.88647
# [36]	validation_0-auc:0.88755
# [37]	validation_0-auc:0.88754
# [39]	validation_0-auc:0.88779
# [44]	validation_0-auc:0.88791
# [30]	validation_0-auc:0.88652
# [37]	validation_0-auc:0.88761
# [38]	validation_0-auc:0.88762
# [40]	validation_0-auc:0.88793
# [45]	validation_0-auc:0.88793
# [31]	validation_0-auc:0.88685
# [39]	validation_0-auc:0.88768
# [38]	validation_0-auc:0.88764
# [41]	validation_0-auc:0.88800
# [46]	validation_0-auc:0.88799
# [32]	validation_0-auc:0.88696
# [40]	validation_0-auc:0.88785
# [39]	validation_0-auc:0.88774
# [47]	validation_0-auc:0.88812
# [42]	validation_0-auc:0.88803
# [33]	validation_0-auc:0.88705
# [41]	validation_0-auc:0.88797
# [40]	validation_0-auc:0.88787
# [48]	validation_0-auc:0.88816
# [43]	validation_0-auc:0.88808
# [34]	validation_0-auc:0.88729
# [42]	validation_0-auc:0.88800
# [41]	validation_0-auc:0.88796
# [44]	validation_0-auc:0.88810
# [49]	validation_0-auc:0.88820
# [35]	validation_0-auc:0.88737
# [43]	validation_0-auc:0.88804
# [42]	validation_0-auc:0.88797
# [45]	validation_0-auc:0.88811
# [50]	validation_0-auc:0.88833
# [36]	validation_0-auc:0.88745
# [44]	validation_0-auc:0.88807
# [46]	validation_0-auc:0.88816
# [43]	validation_0-auc:0.88800
# [51]	validation_0-auc:0.88838
# [37]	validation_0-auc:0.88756
# [45]	validation_0-auc:0.88811
# [44]	validation_0-auc:0.88799
# [52]	validation_0-auc:0.88844
# [47]	validation_0-auc:0.88817
# [38]	validation_0-auc:0.88760
# [46]	validation_0-auc:0.88817
# [45]	validation_0-auc:0.88804
# [53]	validation_0-auc:0.88849
# [48]	validation_0-auc:0.88822
# [39]	validation_0-auc:0.88767
# [47]	validation_0-auc:0.88826
# [54]	validation_0-auc:0.88855
# [46]	validation_0-auc:0.88809
# [40]	validation_0-auc:0.88782
# [49]	validation_0-auc:0.88828
# [47]	validation_0-auc:0.88817
# [48]	validation_0-auc:0.88831
# [41]	validation_0-auc:0.88792
# [55]	validation_0-auc:0.88863
# [50]	validation_0-auc:0.88829
# [48]	validation_0-auc:0.88820
# [42]	validation_0-auc:0.88803
# [51]	validation_0-auc:0.88835
# [49]	validation_0-auc:0.88835
# [56]	validation_0-auc:0.88865
# [43]	validation_0-auc:0.88807
# [49]	validation_0-auc:0.88824
# [50]	validation_0-auc:0.88836
# [44]	validation_0-auc:0.88811
# [52]	validation_0-auc:0.88844
# [57]	validation_0-auc:0.88868
# [50]	validation_0-auc:0.88840
# [45]	validation_0-auc:0.88815
# [53]	validation_0-auc:0.88846
# [58]	validation_0-auc:0.88868
# [51]	validation_0-auc:0.88844
# [46]	validation_0-auc:0.88820
# [54]	validation_0-auc:0.88855
# [52]	validation_0-auc:0.88846
# [51]	validation_0-auc:0.88843
# [59]	validation_0-auc:0.88872
# [47]	validation_0-auc:0.88826
# [55]	validation_0-auc:0.88859
# [53]	validation_0-auc:0.88852
# [60]	validation_0-auc:0.88873
# [48]	validation_0-auc:0.88832
# [52]	validation_0-auc:0.88851
# [56]	validation_0-auc:0.88861
# [61]	validation_0-auc:0.88876
# [53]	validation_0-auc:0.88853
# [49]	validation_0-auc:0.88841
# [57]	validation_0-auc:0.88859
# [54]	validation_0-auc:0.88860
# [62]	validation_0-auc:0.88879
# [54]	validation_0-auc:0.88861
# [50]	validation_0-auc:0.88848
# [58]	validation_0-auc:0.88862
# [63]	validation_0-auc:0.88884
# [55]	validation_0-auc:0.88865
# [59]	validation_0-auc:0.88865
# [56]	validation_0-auc:0.88873
# [55]	validation_0-auc:0.88862
# [51]	validation_0-auc:0.88857
# [60]	validation_0-auc:0.88867
# [64]	validation_0-auc:0.88890
# [56]	validation_0-auc:0.88867
# [57]	validation_0-auc:0.88876
# [65]	validation_0-auc:0.88896
# [52]	validation_0-auc:0.88865
# [61]	validation_0-auc:0.88873
# [57]	validation_0-auc:0.88867
# [58]	validation_0-auc:0.88878
# [66]	validation_0-auc:0.88900
# [53]	validation_0-auc:0.88865
# [62]	validation_0-auc:0.88876
# [58]	validation_0-auc:0.88869
# [59]	validation_0-auc:0.88882
# [67]	validation_0-auc:0.88902
# [63]	validation_0-auc:0.88879
# [54]	validation_0-auc:0.88879
# [60]	validation_0-auc:0.88888
# [59]	validation_0-auc:0.88871
# [68]	validation_0-auc:0.88906
# [64]	validation_0-auc:0.88883
# [55]	validation_0-auc:0.88884
# [61]	validation_0-auc:0.88891
# [69]	validation_0-auc:0.88909
# [60]	validation_0-auc:0.88874
# [65]	validation_0-auc:0.88890
# [62]	validation_0-auc:0.88897
# [61]	validation_0-auc:0.88877
# [70]	validation_0-auc:0.88911
# [66]	validation_0-auc:0.88893
# [63]	validation_0-auc:0.88898
# [62]	validation_0-auc:0.88881
# [56]	validation_0-auc:0.88889
# [71]	validation_0-auc:0.88912
# [67]	validation_0-auc:0.88893
# [64]	validation_0-auc:0.88902
# [63]	validation_0-auc:0.88884
# [72]	validation_0-auc:0.88914
# [68]	validation_0-auc:0.88895
# [65]	validation_0-auc:0.88905
# [57]	validation_0-auc:0.88894
# [64]	validation_0-auc:0.88889
# [73]	validation_0-auc:0.88915
# [69]	validation_0-auc:0.88899
# [66]	validation_0-auc:0.88909
# [74]	validation_0-auc:0.88920
# [65]	validation_0-auc:0.88887
# [70]	validation_0-auc:0.88901
# [67]	validation_0-auc:0.88913
# [58]	validation_0-auc:0.88894
# [75]	validation_0-auc:0.88923
# [66]	validation_0-auc:0.88893
# [71]	validation_0-auc:0.88905
# [68]	validation_0-auc:0.88916
# [67]	validation_0-auc:0.88894
# [76]	validation_0-auc:0.88922
# [72]	validation_0-auc:0.88906
# [69]	validation_0-auc:0.88918
# [59]	validation_0-auc:0.88895
# [77]	validation_0-auc:0.88928
# [68]	validation_0-auc:0.88896
# [73]	validation_0-auc:0.88911
# [70]	validation_0-auc:0.88922
# [78]	validation_0-auc:0.88929
# [69]	validation_0-auc:0.88908
# [60]	validation_0-auc:0.88899
# [74]	validation_0-auc:0.88913
# [71]	validation_0-auc:0.88924
# [79]	validation_0-auc:0.88930
# [70]	validation_0-auc:0.88909
# [75]	validation_0-auc:0.88916
# [72]	validation_0-auc:0.88925
# [61]	validation_0-auc:0.88905
# [80]	validation_0-auc:0.88930
# [71]	validation_0-auc:0.88913
# [76]	validation_0-auc:0.88917
# [73]	validation_0-auc:0.88930
# [72]	validation_0-auc:0.88913
# [81]	validation_0-auc:0.88931
# [77]	validation_0-auc:0.88918
# [62]	validation_0-auc:0.88909
# [73]	validation_0-auc:0.88914
# [82]	validation_0-auc:0.88931
# [74]	validation_0-auc:0.88929
# [78]	validation_0-auc:0.88919
# [83]	validation_0-auc:0.88936
# [74]	validation_0-auc:0.88912
# [75]	validation_0-auc:0.88932
# [79]	validation_0-auc:0.88922
# [84]	validation_0-auc:0.88938
# [75]	validation_0-auc:0.88916
# [76]	validation_0-auc:0.88934
# [63]	validation_0-auc:0.88910
# [85]	validation_0-auc:0.88938
# [76]	validation_0-auc:0.88913
# [77]	validation_0-auc:0.88936
# [80]	validation_0-auc:0.88923
# [86]	validation_0-auc:0.88938
# [77]	validation_0-auc:0.88915
# [78]	validation_0-auc:0.88937
# [81]	validation_0-auc:0.88922
# [64]	validation_0-auc:0.88914
# [78]	validation_0-auc:0.88917
# [79]	validation_0-auc:0.88940
# [82]	validation_0-auc:0.88926
# [87]	validation_0-auc:0.88940
# [65]	validation_0-auc:0.88915
# [80]	validation_0-auc:0.88940
# [83]	validation_0-auc:0.88926
# [88]	validation_0-auc:0.88941
# [66]	validation_0-auc:0.88918
# [79]	validation_0-auc:0.88918[84]	validation_0-auc:0.88928
#
# [81]	validation_0-auc:0.88942
# [89]	validation_0-auc:0.88941
# [67]	validation_0-auc:0.88919
# [85]	validation_0-auc:0.88928
# [82]	validation_0-auc:0.88945
# [90]	validation_0-auc:0.88945
# [80]	validation_0-auc:0.88920
# [83]	validation_0-auc:0.88946
# [91]	validation_0-auc:0.88944
# [86]	validation_0-auc:0.88928
# [81]	validation_0-auc:0.88920
# [68]	validation_0-auc:0.88920
# [84]	validation_0-auc:0.88946
# [92]	validation_0-auc:0.88944
# [87]	validation_0-auc:0.88930
# [82]	validation_0-auc:0.88923
# [85]	validation_0-auc:0.88949
# [93]	validation_0-auc:0.88947
# [88]	validation_0-auc:0.88930
# [83]	validation_0-auc:0.88925
# [94]	validation_0-auc:0.88950[86]	validation_0-auc:0.88950
#
# [89]	validation_0-auc:0.88932
# [69]	validation_0-auc:0.88923
# [84]	validation_0-auc:0.88923
# [95]	validation_0-auc:0.88953
# [90]	validation_0-auc:0.88933
# [87]	validation_0-auc:0.88952
# [96]	validation_0-auc:0.88954
# [85]	validation_0-auc:0.88925
# [70]	validation_0-auc:0.88926
# [91]	validation_0-auc:0.88934
# [88]	validation_0-auc:0.88953
# [86]	validation_0-auc:0.88926
# [71]	validation_0-auc:0.88932
# [89]	validation_0-auc:0.88956
# [97]	validation_0-auc:0.88953
# [92]	validation_0-auc:0.88935
# [87]	validation_0-auc:0.88927
# [72]	validation_0-auc:0.88936
# [98]	validation_0-auc:0.88954
# [90]	validation_0-auc:0.88960
# [88]	validation_0-auc:0.88928
# [93]	validation_0-auc:0.88937
# [73]	validation_0-auc:0.88940
# [99]	validation_0-auc:0.88955
# [89]	validation_0-auc:0.88930
# [91]	validation_0-auc:0.88961
# [94]	validation_0-auc:0.88935
# [100]	validation_0-auc:0.88958
# [90]	validation_0-auc:0.88928
# [74]	validation_0-auc:0.88942
# [95]	validation_0-auc:0.88934
# [101]	validation_0-auc:0.88960
# [92]	validation_0-auc:0.88961
# [91]	validation_0-auc:0.88929
# [96]	validation_0-auc:0.88936
# [102]	validation_0-auc:0.88962
# [75]	validation_0-auc:0.88944
# [93]	validation_0-auc:0.88966
# [92]	validation_0-auc:0.88930
# [97]	validation_0-auc:0.88936
# [103]	validation_0-auc:0.88963
# [94]	validation_0-auc:0.88965
# [93]	validation_0-auc:0.88931
# [98]	validation_0-auc:0.88937
# [104]	validation_0-auc:0.88962
# [95]	validation_0-auc:0.88967
# [76]	validation_0-auc:0.88946
# [94]	validation_0-auc:0.88933
# [99]	validation_0-auc:0.88937
# [105]	validation_0-auc:0.88964
# [95]	validation_0-auc:0.88932
# [96]	validation_0-auc:0.88969
# [100]	validation_0-auc:0.88936
# [77]	validation_0-auc:0.88946
# [106]	validation_0-auc:0.88965
# [96]	validation_0-auc:0.88930
# [101]	validation_0-auc:0.88937
# [107]	validation_0-auc:0.88963
# [97]	validation_0-auc:0.88968
# [97]	validation_0-auc:0.88929
# [102]	validation_0-auc:0.88940
# [78]	validation_0-auc:0.88950
# [108]	validation_0-auc:0.88960
# [98]	validation_0-auc:0.88932
# [103]	validation_0-auc:0.88941
# [98]	validation_0-auc:0.88967
# [79]	validation_0-auc:0.88953
# [109]	validation_0-auc:0.88959
# [99]	validation_0-auc:0.88934
# [99]	validation_0-auc:0.88968
# [80]	validation_0-auc:0.88955
# [110]	validation_0-auc:0.88959
# [104]	validation_0-auc:0.88940
# [100]	validation_0-auc:0.88934
# [100]	validation_0-auc:0.88971
# [111]	validation_0-auc:0.88961
# [101]	validation_0-auc:0.88936
# [105]	validation_0-auc:0.88940
# [81]	validation_0-auc:0.88955
# [101]	validation_0-auc:0.88970
# [102]	validation_0-auc:0.88937
# [106]	validation_0-auc:0.88939
# [82]	validation_0-auc:0.88958
# [102]	validation_0-auc:0.88970
# [103]	validation_0-auc:0.88940
# [107]	validation_0-auc:0.88939
# [112]	validation_0-auc:0.88960
# [83]	validation_0-auc:0.88962
# [103]	validation_0-auc:0.88973
# [108]	validation_0-auc:0.88938
# [113]	validation_0-auc:0.88962
# [104]	validation_0-auc:0.88937
# [104]	validation_0-auc:0.88974
# [105]	validation_0-auc:0.88937
# [114]	validation_0-auc:0.88963
# [84]	validation_0-auc:0.88963
# [109]	validation_0-auc:0.88935
# [105]	validation_0-auc:0.88974
# [106]	validation_0-auc:0.88936
# [110]	validation_0-auc:0.88933
# [115]	validation_0-auc:0.88963
# [85]	validation_0-auc:0.88963
# [106]	validation_0-auc:0.88975
# [107]	validation_0-auc:0.88937
# [111]	validation_0-auc:0.88934
# [86]	validation_0-auc:0.88962
# [116]	validation_0-auc:0.88962
# [107]	validation_0-auc:0.88974
# [108]	validation_0-auc:0.88935
# [87]	validation_0-auc:0.88963
# [112]	validation_0-auc:0.88936
# [108]	validation_0-auc:0.88974
# [109]	validation_0-auc:0.88939
# [117]	validation_0-auc:0.88964
# [113]	validation_0-auc:0.88935
# [88]	validation_0-auc:0.88966
# [118]	validation_0-auc:0.88963
# [110]	validation_0-auc:0.88939
# [114]	validation_0-auc:0.88937
# [109]	validation_0-auc:0.88976
# [89]	validation_0-auc:0.88970
# [119]	validation_0-auc:0.88965
# [115]	validation_0-auc:0.88937
# [90]	validation_0-auc:0.88971
# [111]	validation_0-auc:0.88938
# [116]	validation_0-auc:0.88935
# [120]	validation_0-auc:0.88965
# [91]	validation_0-auc:0.88970
# [117]	validation_0-auc:0.88937
# [121]	validation_0-auc:0.88966
# [118]	validation_0-auc:0.88938
# [110]	validation_0-auc:0.88978
# [122]	validation_0-auc:0.88964
# [112]	validation_0-auc:0.88939
# [92]	validation_0-auc:0.88970
# [111]	validation_0-auc:0.88979
# [113]	validation_0-auc:0.88938
# [112]	validation_0-auc:0.88981
# [123]	validation_0-auc:0.88966
# [119]	validation_0-auc:0.88936
# [93]	validation_0-auc:0.88974
# [114]	validation_0-auc:0.88940
# [113]	validation_0-auc:0.88983
# [124]	validation_0-auc:0.88966
# [115]	validation_0-auc:0.88941
# [94]	validation_0-auc:0.88975
# [120]	validation_0-auc:0.88938
# [125]	validation_0-auc:0.88964
# [114]	validation_0-auc:0.88982
# [121]	validation_0-auc:0.88938
# [116]	validation_0-auc:0.88942
# [115]	validation_0-auc:0.88983
# [122]	validation_0-auc:0.88939
# [126]	validation_0-auc:0.88966
# [117]	validation_0-auc:0.88941
# [95]	validation_0-auc:0.88976
# [116]	validation_0-auc:0.88982
# [123]	validation_0-auc:0.88937
# [118]	validation_0-auc:0.88941
# [127]	validation_0-auc:0.88968
# [96]	validation_0-auc:0.88976
# [117]	validation_0-auc:0.88984
# [124]	validation_0-auc:0.88938
# [119]	validation_0-auc:0.88941
# [97]	validation_0-auc:0.88975
# [128]	validation_0-auc:0.88970
# [118]	validation_0-auc:0.88986
# [125]	validation_0-auc:0.88940
# [120]	validation_0-auc:0.88940
# [98]	validation_0-auc:0.88977
# [129]	validation_0-auc:0.88971
# [126]	validation_0-auc:0.88939
# [119]	validation_0-auc:0.88985
# [121]	validation_0-auc:0.88940
# [99]	validation_0-auc:0.88977
# [127]	validation_0-auc:0.88939
# [130]	validation_0-auc:0.88973
# [120]	validation_0-auc:0.88985
# [122]	validation_0-auc:0.88940
# [100]	validation_0-auc:0.88978
# [131]	validation_0-auc:0.88973
# [128]	validation_0-auc:0.88938
# [121]	validation_0-auc:0.88986
# [101]	validation_0-auc:0.88976
# [123]	validation_0-auc:0.88943
# [132]	validation_0-auc:0.88970
# [124]	validation_0-auc:0.88940
# [102]	validation_0-auc:0.88976
# [129]	validation_0-auc:0.88937
# [122]	validation_0-auc:0.88988
# [133]	validation_0-auc:0.88971
# [130]	validation_0-auc:0.88937
# [103]	validation_0-auc:0.88975
# [123]	validation_0-auc:0.88986
# [125]	validation_0-auc:0.88941
# [131]	validation_0-auc:0.88937
# [104]	validation_0-auc:0.88976
# [124]	validation_0-auc:0.88984
# [134]	validation_0-auc:0.88972
# [126]	validation_0-auc:0.88943
# [132]	validation_0-auc:0.88940
# [135]	validation_0-auc:0.88972
# [125]	validation_0-auc:0.88983
# [127]	validation_0-auc:0.88944
# [133]	validation_0-auc:0.88938
# [105]	validation_0-auc:0.88979
# [126]	validation_0-auc:0.88984
# [136]	validation_0-auc:0.88972
# [128]	validation_0-auc:0.88944
# [134]	validation_0-auc:0.88940
# [106]	validation_0-auc:0.88978
# [127]	validation_0-auc:0.88983
# [137]	validation_0-auc:0.88974
# [107]	validation_0-auc:0.88978
# [129]	validation_0-auc:0.88943
# [135]	validation_0-auc:0.88945
# [128]	validation_0-auc:0.88982
# [138]	validation_0-auc:0.88974
# [108]	validation_0-auc:0.88979
# [136]	validation_0-auc:0.88944
# [139]	validation_0-auc:0.88974[129]	validation_0-auc:0.88980
#
# [130]	validation_0-auc:0.88939
# [109]	validation_0-auc:0.88984
# [130]	validation_0-auc:0.88979
# [137]	validation_0-auc:0.88944
# [131]	validation_0-auc:0.88938
# [140]	validation_0-auc:0.88975
# [110]	validation_0-auc:0.88986
# [138]	validation_0-auc:0.88942
# [131]	validation_0-auc:0.88980
# [132]	validation_0-auc:0.88938
# [141]	validation_0-auc:0.88976
# [139]	validation_0-auc:0.88943
# [111]	validation_0-auc:0.88982
# [132]	validation_0-auc:0.88976
# [133]	validation_0-auc:0.88938
# [142]	validation_0-auc:0.88977
# [133]	validation_0-auc:0.88975
# [140]	validation_0-auc:0.88941
# [134]	validation_0-auc:0.88938
# [143]	validation_0-auc:0.88979
# [112]	validation_0-auc:0.88985
# [141]	validation_0-auc:0.88942
# [113]	validation_0-auc:0.88982
# [134]	validation_0-auc:0.88976
# [135]	validation_0-auc:0.88939
# [142]	validation_0-auc:0.88939
# [144]	validation_0-auc:0.88979
# [114]	validation_0-auc:0.88982
# [136]	validation_0-auc:0.88939
# [145]	validation_0-auc:0.88981
# [143]	validation_0-auc:0.88941
# [137]	validation_0-auc:0.88941
# [135]	validation_0-auc:0.88977
# [115]	validation_0-auc:0.88983
# [144]	validation_0-auc:0.88942
# [136]	validation_0-auc:0.88977
# [146]	validation_0-auc:0.88982
# [138]	validation_0-auc:0.88944
# [116]	validation_0-auc:0.88982
# [145]	validation_0-auc:0.88941
# [137]	validation_0-auc:0.88978
# [139]	validation_0-auc:0.88941
# [117]	validation_0-auc:0.88982
# [147]	validation_0-auc:0.88979
# [146]	validation_0-auc:0.88942
# [118]	validation_0-auc:0.88983
# [138]	validation_0-auc:0.88980
# [140]	validation_0-auc:0.88940
# [147]	validation_0-auc:0.88942
# [119]	validation_0-auc:0.88984
# [141]	validation_0-auc:0.88941
# [139]	validation_0-auc:0.88978
# [148]	validation_0-auc:0.88978
# [142]	validation_0-auc:0.88942
# [120]	validation_0-auc:0.88985
# [148]	validation_0-auc:0.88943
# [140]	validation_0-auc:0.88980
# [143]	validation_0-auc:0.88940
# [121]	validation_0-auc:0.88986[149]	validation_0-auc:0.88980
# [141]	validation_0-auc:0.88980
#
# [144]	validation_0-auc:0.88939
# [149]	validation_0-auc:0.88942
# [150]	validation_0-auc:0.88981
# [142]	validation_0-auc:0.88981
# [145]	validation_0-auc:0.88941
# [150]	validation_0-auc:0.88943
# [122]	validation_0-auc:0.88987
# [143]	validation_0-auc:0.88981
# [151]	validation_0-auc:0.88981
# [151]	validation_0-auc:0.88943
# [123]	validation_0-auc:0.88987
# [152]	validation_0-auc:0.88981
# [144]	validation_0-auc:0.88980
# [146]	validation_0-auc:0.88940
# [152]	validation_0-auc:0.88942
# [124]	validation_0-auc:0.88988
# [145]	validation_0-auc:0.88979
# [153]	validation_0-auc:0.88982
# [153]	validation_0-auc:0.88944
# [147]	validation_0-auc:0.88939
# [154]	validation_0-auc:0.88981
# [146]	validation_0-auc:0.88981
# [125]	validation_0-auc:0.88989
# [154]	validation_0-auc:0.88943
# [148]	validation_0-auc:0.88942
# [155]	validation_0-auc:0.88981
# [126]	validation_0-auc:0.88992
# [155]	validation_0-auc:0.88940
# [147]	validation_0-auc:0.88980
# [156]	validation_0-auc:0.88982
# [149]	validation_0-auc:0.88942
# [127]	validation_0-auc:0.88992
# [156]	validation_0-auc:0.88942
# [150]	validation_0-auc:0.88942
# [148]	validation_0-auc:0.88981
# [157]	validation_0-auc:0.88980
# [157]	validation_0-auc:0.88943
# [128]	validation_0-auc:0.88994
# [151]	validation_0-auc:0.88941
# [149]	validation_0-auc:0.88980
# [158]	validation_0-auc:0.88982
# [158]	validation_0-auc:0.88943
# [152]	validation_0-auc:0.88940
# [150]	validation_0-auc:0.88981
# [159]	validation_0-auc:0.88979
# [129]	validation_0-auc:0.88993
# [159]	validation_0-auc:0.88942
# [153]	validation_0-auc:0.88939
# [160]	validation_0-auc:0.88980
# [151]	validation_0-auc:0.88979
# [130]	validation_0-auc:0.88994
# [160]	validation_0-auc:0.88942
# [154]	validation_0-auc:0.88938
# [131]	validation_0-auc:0.88993
# [152]	validation_0-auc:0.88981
# [161]	validation_0-auc:0.88942
# [155]	validation_0-auc:0.88938
# [161]	validation_0-auc:0.88979
# [132]	validation_0-auc:0.88996
# [162]	validation_0-auc:0.88944
# [153]	validation_0-auc:0.88977
# [162]	validation_0-auc:0.88982
# [156]	validation_0-auc:0.88938
# [163]	validation_0-auc:0.88944
# [154]	validation_0-auc:0.88978
# [133]	validation_0-auc:0.88997
# [163]	validation_0-auc:0.88982
# [164]	validation_0-auc:0.88943
# [157]	validation_0-auc:0.88939
# [155]	validation_0-auc:0.88979
# [134]	validation_0-auc:0.88997
# [164]	validation_0-auc:0.88982
# [158]	validation_0-auc:0.88940
# [165]	validation_0-auc:0.88941
# [156]	validation_0-auc:0.88980
# [135]	validation_0-auc:0.88997
# [157]	validation_0-auc:0.88980
# [159]	validation_0-auc:0.88941
# [166]	validation_0-auc:0.88940
# [165]	validation_0-auc:0.88982
# [136]	validation_0-auc:0.88998
# [158]	validation_0-auc:0.88980
# [167]	validation_0-auc:0.88940
# [160]	validation_0-auc:0.88941
# [166]	validation_0-auc:0.88984
# [137]	validation_0-auc:0.88999
# [161]	validation_0-auc:0.88943
# [159]	validation_0-auc:0.88979
# [168]	validation_0-auc:0.88940
# [167]	validation_0-auc:0.88984
# [162]	validation_0-auc:0.88942
# [138]	validation_0-auc:0.88998
# [168]	validation_0-auc:0.88982
# [169]	validation_0-auc:0.88942
# [163]	validation_0-auc:0.88943
# [139]	validation_0-auc:0.88999
# [160]	validation_0-auc:0.88979
# [170]	validation_0-auc:0.88939
# [164]	validation_0-auc:0.88944
# [140]	validation_0-auc:0.88999
# [161]	validation_0-auc:0.88981
# [169]	validation_0-auc:0.88983
# [165]	validation_0-auc:0.88944
# [171]	validation_0-auc:0.88941
# [162]	validation_0-auc:0.88981
# [141]	validation_0-auc:0.88999
# [170]	validation_0-auc:0.88982
# [166]	validation_0-auc:0.88942
# [163]	validation_0-auc:0.88981
# [171]	validation_0-auc:0.88983
# [142]	validation_0-auc:0.88997
# [172]	validation_0-auc:0.88944
# [164]	validation_0-auc:0.88982
# [173]	validation_0-auc:0.88942
# [143]	validation_0-auc:0.88996
# [172]	validation_0-auc:0.88983
# [165]	validation_0-auc:0.88983
# [174]	validation_0-auc:0.88944
# [167]	validation_0-auc:0.88940
# [173]	validation_0-auc:0.88982
# [144]	validation_0-auc:0.88997
# [175]	validation_0-auc:0.88944
# [168]	validation_0-auc:0.88937
# [174]	validation_0-auc:0.88982
# [145]	validation_0-auc:0.88997
# [176]	validation_0-auc:0.88947
# [166]	validation_0-auc:0.88984
# [175]	validation_0-auc:0.88984
# [169]	validation_0-auc:0.88938
# [146]	validation_0-auc:0.88996
# [177]	validation_0-auc:0.88946
# [167]	validation_0-auc:0.88985
# [176]	validation_0-auc:0.88983
# [147]	validation_0-auc:0.88995
# [170]	validation_0-auc:0.88938
# [178]	validation_0-auc:0.88942
# [168]	validation_0-auc:0.88984
# [148]	validation_0-auc:0.88995
# [177]	validation_0-auc:0.88983
# [179]	validation_0-auc:0.88943
# [169]	validation_0-auc:0.88984
# [171]	validation_0-auc:0.88937
# [149]	validation_0-auc:0.88995
# [170]	validation_0-auc:0.88983
# [178]	validation_0-auc:0.88982
# [172]	validation_0-auc:0.88937
# [150]	validation_0-auc:0.88993
# [171]	validation_0-auc:0.88983
# [180]	validation_0-auc:0.88943
# [179]	validation_0-auc:0.88981
# [173]	validation_0-auc:0.88935
# [172]	validation_0-auc:0.88985
# [181]	validation_0-auc:0.88943
# [180]	validation_0-auc:0.88981
# [174]	validation_0-auc:0.88935
# [151]	validation_0-auc:0.88991
# [173]	validation_0-auc:0.88985
# [182]	validation_0-auc:0.88942
# [181]	validation_0-auc:0.88982
# [175]	validation_0-auc:0.88936
# [152]	validation_0-auc:0.88991
# [183]	validation_0-auc:0.88941
# [182]	validation_0-auc:0.88988
# [153]	validation_0-auc:0.88992
# [174]	validation_0-auc:0.88985
# [176]	validation_0-auc:0.88936
# [184]	validation_0-auc:0.88941
# [154]	validation_0-auc:0.88992
# [175]	validation_0-auc:0.88987
# [183]	validation_0-auc:0.88988
# [185]	validation_0-auc:0.88941
# [177]	validation_0-auc:0.88936
# [155]	validation_0-auc:0.88993
# [176]	validation_0-auc:0.88986
# [178]	validation_0-auc:0.88936
# [184]	validation_0-auc:0.88986
# [186]	validation_0-auc:0.88941
# [156]	validation_0-auc:0.88991
# [177]	validation_0-auc:0.88985
# [185]	validation_0-auc:0.88985
# [187]	validation_0-auc:0.88940
# [179]	validation_0-auc:0.88936
# [157]	validation_0-auc:0.88991
# [178]	validation_0-auc:0.88985
# [186]	validation_0-auc:0.88987
# [188]	validation_0-auc:0.88940
# [179]	validation_0-auc:0.88985
# [180]	validation_0-auc:0.88935
# [158]	validation_0-auc:0.88992
# [189]	validation_0-auc:0.88939
# [187]	validation_0-auc:0.88988
# [180]	validation_0-auc:0.88985
# [181]	validation_0-auc:0.88935
# [159]	validation_0-auc:0.88992
# [190]	validation_0-auc:0.88940
# [188]	validation_0-auc:0.88989
# [181]	validation_0-auc:0.88986
# [160]	validation_0-auc:0.88994
# [182]	validation_0-auc:0.88936
# [191]	validation_0-auc:0.88940
# [182]	validation_0-auc:0.88988
# [189]	validation_0-auc:0.88989
# [161]	validation_0-auc:0.88993
# [183]	validation_0-auc:0.88937
# [183]	validation_0-auc:0.88988
# [192]	validation_0-auc:0.88939
# [162]	validation_0-auc:0.88995
# [190]	validation_0-auc:0.88988
# [184]	validation_0-auc:0.88934
# [184]	validation_0-auc:0.88986
# [163]	validation_0-auc:0.88994
# [191]	validation_0-auc:0.88989
# [185]	validation_0-auc:0.88934
# [193]	validation_0-auc:0.88939
# [185]	validation_0-auc:0.88984
# [164]	validation_0-auc:0.88994
# [192]	validation_0-auc:0.88988
# [186]	validation_0-auc:0.88935
# [186]	validation_0-auc:0.88985
# [194]	validation_0-auc:0.88940
# [165]	validation_0-auc:0.88997
# [193]	validation_0-auc:0.88986
# [187]	validation_0-auc:0.88934
# [187]	validation_0-auc:0.88986
# [195]	validation_0-auc:0.88940
# [166]	validation_0-auc:0.88996
# [188]	validation_0-auc:0.88933
# [188]	validation_0-auc:0.88988
# [194]	validation_0-auc:0.88986
# [196]	validation_0-auc:0.88940
# [167]	validation_0-auc:0.88996
# [189]	validation_0-auc:0.88988
# [189]	validation_0-auc:0.88933
# [195]	validation_0-auc:0.88987
# [197]	validation_0-auc:0.88941
# [168]	validation_0-auc:0.88997
# [190]	validation_0-auc:0.88990
# [196]	validation_0-auc:0.88987
# [190]	validation_0-auc:0.88932
# [198]	validation_0-auc:0.88941
# [191]	validation_0-auc:0.88989
# [191]	validation_0-auc:0.88932
# [197]	validation_0-auc:0.88987
# [199]	validation_0-auc:0.88941
# [169]	validation_0-auc:0.88996
# [192]	validation_0-auc:0.88990
# [198]	validation_0-auc:0.88987
# [192]	validation_0-auc:0.88931
# [200]	validation_0-auc:0.88941
# [170]	validation_0-auc:0.88996
# [199]	validation_0-auc:0.88986
# [193]	validation_0-auc:0.88932
# [193]	validation_0-auc:0.88990
# [201]	validation_0-auc:0.88940
# [171]	validation_0-auc:0.88997
# [200]	validation_0-auc:0.88986
# [194]	validation_0-auc:0.88932
# [194]	validation_0-auc:0.88990
# [202]	validation_0-auc:0.88940
# [172]	validation_0-auc:0.88997
# [201]	validation_0-auc:0.88985
# [195]	validation_0-auc:0.88992
# [195]	validation_0-auc:0.88935
# [203]	validation_0-auc:0.88940
# [202]	validation_0-auc:0.88985
# [196]	validation_0-auc:0.88992
# [196]	validation_0-auc:0.88933
# [204]	validation_0-auc:0.88939
# [173]	validation_0-auc:0.88998
# [203]	validation_0-auc:0.88986
# [197]	validation_0-auc:0.88991
# [197]	validation_0-auc:0.88933
# [204]	validation_0-auc:0.88984
# [205]	validation_0-auc:0.88938
# [198]	validation_0-auc:0.88992
# [174]	validation_0-auc:0.89000
# [198]	validation_0-auc:0.88932
# [206]	validation_0-auc:0.88940
# [205]	validation_0-auc:0.88983
# [175]	validation_0-auc:0.89001
# [199]	validation_0-auc:0.88993
# [199]	validation_0-auc:0.88933
# [206]	validation_0-auc:0.88983
# [207]	validation_0-auc:0.88941
# [176]	validation_0-auc:0.88999
# [200]	validation_0-auc:0.88992
# [207]	validation_0-auc:0.88983
# [200]	validation_0-auc:0.88930
# [177]	validation_0-auc:0.88997
# [208]	validation_0-auc:0.88941
# [201]	validation_0-auc:0.88992
# [208]	validation_0-auc:0.88984
# [178]	validation_0-auc:0.88997
# [201]	validation_0-auc:0.88929
# [209]	validation_0-auc:0.88980
# [209]	validation_0-auc:0.88942
# [202]	validation_0-auc:0.88991
# [179]	validation_0-auc:0.88993
# [202]	validation_0-auc:0.88929
# [210]	validation_0-auc:0.88942
# [203]	validation_0-auc:0.88989
# [180]	validation_0-auc:0.88991
# [210]	validation_0-auc:0.88984
# [211]	validation_0-auc:0.88943
# [203]	validation_0-auc:0.88930
# [204]	validation_0-auc:0.88988
# [181]	validation_0-auc:0.88993
# [211]	validation_0-auc:0.88984
# [212]	validation_0-auc:0.88943
# [182]	validation_0-auc:0.88995
# [204]	validation_0-auc:0.88931
# [212]	validation_0-auc:0.88985
# [213]	validation_0-auc:0.88941
# [205]	validation_0-auc:0.88989
# [183]	validation_0-auc:0.88995
# [213]	validation_0-auc:0.88984
# [206]	validation_0-auc:0.88988
# [214]	validation_0-auc:0.88942
# [205]	validation_0-auc:0.88930
# [184]	validation_0-auc:0.88997
# [207]	validation_0-auc:0.88985
# [214]	validation_0-auc:0.88985
# [206]	validation_0-auc:0.88930
# [185]	validation_0-auc:0.88998
# [215]	validation_0-auc:0.88940
# [215]	validation_0-auc:0.88986
# [207]	validation_0-auc:0.88930
# [186]	validation_0-auc:0.89000
# [208]	validation_0-auc:0.88983
# [216]	validation_0-auc:0.88988
# [187]	validation_0-auc:0.89000
# [208]	validation_0-auc:0.88931
# [209]	validation_0-auc:0.88981
# [216]	validation_0-auc:0.88940
# [209]	validation_0-auc:0.88930
# [210]	validation_0-auc:0.88981
# [217]	validation_0-auc:0.88940
# [188]	validation_0-auc:0.89001
# [217]	validation_0-auc:0.88990
# [211]	validation_0-auc:0.88983
# [210]	validation_0-auc:0.88928
# [218]	validation_0-auc:0.88939
# [218]	validation_0-auc:0.88987
# [189]	validation_0-auc:0.89001
# [211]	validation_0-auc:0.88926
# [219]	validation_0-auc:0.88941
# [219]	validation_0-auc:0.88986
# [190]	validation_0-auc:0.89000
# [212]	validation_0-auc:0.88985
# [220]	validation_0-auc:0.88985
# [220]	validation_0-auc:0.88941
# [213]	validation_0-auc:0.88983
# [191]	validation_0-auc:0.89000
# [212]	validation_0-auc:0.88925
# [221]	validation_0-auc:0.88984
# [221]	validation_0-auc:0.88940
# [214]	validation_0-auc:0.88984
# [192]	validation_0-auc:0.89001
# [213]	validation_0-auc:0.88924
# [215]	validation_0-auc:0.88981
# [222]	validation_0-auc:0.88984
# [214]	validation_0-auc:0.88923
# [193]	validation_0-auc:0.89001
# [222]	validation_0-auc:0.88941
# [223]	validation_0-auc:0.88982
# [194]	validation_0-auc:0.89001
# [215]	validation_0-auc:0.88920
# [223]	validation_0-auc:0.88940
# [216]	validation_0-auc:0.88980
# [224]	validation_0-auc:0.88982
# [216]	validation_0-auc:0.88918
# [224]	validation_0-auc:0.88941
# [217]	validation_0-auc:0.88981
# [225]	validation_0-auc:0.88984
# [217]	validation_0-auc:0.88921
# [195]	validation_0-auc:0.89003
# [225]	validation_0-auc:0.88940
# [218]	validation_0-auc:0.88980
# [226]	validation_0-auc:0.88985
# [218]	validation_0-auc:0.88919
# [226]	validation_0-auc:0.88939
# [196]	validation_0-auc:0.89004
# [227]	validation_0-auc:0.88984
# [219]	validation_0-auc:0.88919
# [227]	validation_0-auc:0.88935
# [197]	validation_0-auc:0.89005
# [219]	validation_0-auc:0.88980
# [228]	validation_0-auc:0.88983
# [228]	validation_0-auc:0.88936
# [220]	validation_0-auc:0.88980
# [198]	validation_0-auc:0.89005
# [220]	validation_0-auc:0.88917
# [229]	validation_0-auc:0.88938
# [221]	validation_0-auc:0.88980
# [199]	validation_0-auc:0.89006
# [221]	validation_0-auc:0.88918
# [229]	validation_0-auc:0.88984
# [230]	validation_0-auc:0.88939
# [222]	validation_0-auc:0.88981
# [222]	validation_0-auc:0.88919
# [230]	validation_0-auc:0.88982
# [200]	validation_0-auc:0.89006
# [223]	validation_0-auc:0.88980
# [231]	validation_0-auc:0.88982
# [223]	validation_0-auc:0.88917
# [231]	validation_0-auc:0.88938
# [201]	validation_0-auc:0.89007
# [224]	validation_0-auc:0.88978
# [232]	validation_0-auc:0.88982
# [202]	validation_0-auc:0.89006
# [224]	validation_0-auc:0.88916
# [232]	validation_0-auc:0.88939
# [225]	validation_0-auc:0.88978
# [233]	validation_0-auc:0.88985
# [203]	validation_0-auc:0.89005
# [225]	validation_0-auc:0.88914
# [226]	validation_0-auc:0.88978
# [234]	validation_0-auc:0.88984
# [204]	validation_0-auc:0.89005
# [233]	validation_0-auc:0.88941
# [226]	validation_0-auc:0.88913
# [235]	validation_0-auc:0.88983
# [227]	validation_0-auc:0.88979
# [227]	validation_0-auc:0.88911
# [205]	validation_0-auc:0.89003
# [234]	validation_0-auc:0.88939
# [236]	validation_0-auc:0.88981
# [228]	validation_0-auc:0.88979
# [228]	validation_0-auc:0.88911
# [235]	validation_0-auc:0.88938
# [206]	validation_0-auc:0.89003
# [237]	validation_0-auc:0.88981
# [229]	validation_0-auc:0.88979
# [229]	validation_0-auc:0.88910
# [207]	validation_0-auc:0.89003
# [238]	validation_0-auc:0.88981
# [230]	validation_0-auc:0.88978
# [230]	validation_0-auc:0.88909
# [236]	validation_0-auc:0.88936
# [208]	validation_0-auc:0.89002
# [239]	validation_0-auc:0.88979
# [231]	validation_0-auc:0.88909
# [231]	validation_0-auc:0.88978
# [237]	validation_0-auc:0.88934
# [209]	validation_0-auc:0.89003
# [232]	validation_0-auc:0.88912
# [240]	validation_0-auc:0.88978
# [210]	validation_0-auc:0.89004
# [232]	validation_0-auc:0.88977
# [238]	validation_0-auc:0.88932
# [233]	validation_0-auc:0.88911
# [241]	validation_0-auc:0.88978
# [233]	validation_0-auc:0.88978
# [239]	validation_0-auc:0.88932
# [234]	validation_0-auc:0.88910
# [211]	validation_0-auc:0.89004
# [242]	validation_0-auc:0.88979
# [234]	validation_0-auc:0.88978
# [235]	validation_0-auc:0.88910
# [212]	validation_0-auc:0.89004
# [243]	validation_0-auc:0.88979
# [240]	validation_0-auc:0.88932
# [236]	validation_0-auc:0.88911
# [244]	validation_0-auc:0.88978
# [213]	validation_0-auc:0.89005
# [235]	validation_0-auc:0.88976
# [241]	validation_0-auc:0.88931
# [237]	validation_0-auc:0.88910
# [245]	validation_0-auc:0.88978
# [214]	validation_0-auc:0.89004
# [236]	validation_0-auc:0.88977
# [238]	validation_0-auc:0.88911
# [242]	validation_0-auc:0.88930
# [237]	validation_0-auc:0.88979
# [246]	validation_0-auc:0.88977
# [215]	validation_0-auc:0.89005
# [239]	validation_0-auc:0.88909
# [243]	validation_0-auc:0.88930
# [238]	validation_0-auc:0.88978
# [216]	validation_0-auc:0.89005
# [240]	validation_0-auc:0.88914
# [244]	validation_0-auc:0.88929
# [247]	validation_0-auc:0.88976
# [217]	validation_0-auc:0.89005
# [241]	validation_0-auc:0.88913
# [248]	validation_0-auc:0.88975
# [239]	validation_0-auc:0.88978
# [245]	validation_0-auc:0.88928
# [249]	validation_0-auc:0.88978[218]	validation_0-auc:0.89002
#
# [240]	validation_0-auc:0.88977
# [246]	validation_0-auc:0.88928
# [250]	validation_0-auc:0.88980
# [219]	validation_0-auc:0.89003
# [242]	validation_0-auc:0.88914
# [241]	validation_0-auc:0.88977
# [247]	validation_0-auc:0.88928
# [251]	validation_0-auc:0.88980
# [220]	validation_0-auc:0.89002
# [242]	validation_0-auc:0.88978
# [243]	validation_0-auc:0.88911
# [248]	validation_0-auc:0.88928
# [221]	validation_0-auc:0.89003
# [243]	validation_0-auc:0.88975
# [244]	validation_0-auc:0.88911
# [249]	validation_0-auc:0.88930
# [252]	validation_0-auc:0.88978
# [222]	validation_0-auc:0.89000
# [244]	validation_0-auc:0.88974
# [250]	validation_0-auc:0.88931
# [253]	validation_0-auc:0.88978
# [245]	validation_0-auc:0.88910
# [223]	validation_0-auc:0.89001
# [245]	validation_0-auc:0.88973
# [251]	validation_0-auc:0.88930
# [254]	validation_0-auc:0.88978
# [246]	validation_0-auc:0.88912
# [246]	validation_0-auc:0.88973
# [224]	validation_0-auc:0.89003
# [252]	validation_0-auc:0.88932
# [255]	validation_0-auc:0.88978
# [247]	validation_0-auc:0.88910
# [247]	validation_0-auc:0.88972
# [225]	validation_0-auc:0.89003
# [256]	validation_0-auc:0.88979
# [253]	validation_0-auc:0.88932
# [248]	validation_0-auc:0.88910
# [248]	validation_0-auc:0.88971
# [226]	validation_0-auc:0.89006
# [257]	validation_0-auc:0.88976
# [254]	validation_0-auc:0.88932
# [249]	validation_0-auc:0.88909
# [227]	validation_0-auc:0.89005
# [258]	validation_0-auc:0.88974
# [249]	validation_0-auc:0.88969
# [255]	validation_0-auc:0.88934
# [228]	validation_0-auc:0.89006
# [250]	validation_0-auc:0.88907
# [259]	validation_0-auc:0.88973
# [250]	validation_0-auc:0.88968
# [256]	validation_0-auc:0.88931
# [251]	validation_0-auc:0.88908
# [260]	validation_0-auc:0.88971
# [257]	validation_0-auc:0.88932
# [229]	validation_0-auc:0.89005
# [251]	validation_0-auc:0.88967
# [252]	validation_0-auc:0.88906
# [261]	validation_0-auc:0.88971
# [230]	validation_0-auc:0.89002
# [252]	validation_0-auc:0.88968
# [258]	validation_0-auc:0.88931
# [253]	validation_0-auc:0.88904
# [262]	validation_0-auc:0.88972
# [253]	validation_0-auc:0.88968
# [259]	validation_0-auc:0.88931
# [254]	validation_0-auc:0.88905
# [231]	validation_0-auc:0.89004
# [263]	validation_0-auc:0.88973
# [254]	validation_0-auc:0.88968
# [255]	validation_0-auc:0.88905
# [232]	validation_0-auc:0.89004
# [264]	validation_0-auc:0.88976
# [260]	validation_0-auc:0.88931
# [255]	validation_0-auc:0.88970
# [256]	validation_0-auc:0.88902
# [233]	validation_0-auc:0.89005
# [265]	validation_0-auc:0.88977
# [261]	validation_0-auc:0.88931
# [256]	validation_0-auc:0.88969
# [257]	validation_0-auc:0.88900
# [234]	validation_0-auc:0.89006
# [262]	validation_0-auc:0.88932
# [266]	validation_0-auc:0.88976
# [257]	validation_0-auc:0.88968
# [258]	validation_0-auc:0.88900
# [263]	validation_0-auc:0.88932
# [258]	validation_0-auc:0.88968
# [267]	validation_0-auc:0.88979
# [235]	validation_0-auc:0.89005
# [259]	validation_0-auc:0.88901
# [259]	validation_0-auc:0.88969
# [264]	validation_0-auc:0.88933
# [236]	validation_0-auc:0.89004
# [260]	validation_0-auc:0.88902
# [268]	validation_0-auc:0.88980
# [260]	validation_0-auc:0.88969
# [265]	validation_0-auc:0.88932
# [237]	validation_0-auc:0.89004
# [261]	validation_0-auc:0.88901
# [261]	validation_0-auc:0.88970
# [269]	validation_0-auc:0.88981
# [266]	validation_0-auc:0.88932
# [262]	validation_0-auc:0.88901
# [262]	validation_0-auc:0.88971
# [238]	validation_0-auc:0.89004
# [270]	validation_0-auc:0.88982
# [263]	validation_0-auc:0.88902
# [239]	validation_0-auc:0.89004
# [263]	validation_0-auc:0.88977
# [271]	validation_0-auc:0.88982
# [267]	validation_0-auc:0.88930
# [264]	validation_0-auc:0.88900
# [240]	validation_0-auc:0.89006
# [272]	validation_0-auc:0.88980
# [268]	validation_0-auc:0.88930
# [265]	validation_0-auc:0.88900
# [264]	validation_0-auc:0.88976
# [273]	validation_0-auc:0.88980
# [269]	validation_0-auc:0.88930
# [265]	validation_0-auc:0.88977
# [266]	validation_0-auc:0.88899
# [241]	validation_0-auc:0.89005
# [274]	validation_0-auc:0.88983
# [270]	validation_0-auc:0.88929
# [266]	validation_0-auc:0.88977
# [267]	validation_0-auc:0.88900
# [275]	validation_0-auc:0.88981
# [271]	validation_0-auc:0.88929
# [267]	validation_0-auc:0.88978
# [268]	validation_0-auc:0.88899
# [276]	validation_0-auc:0.88981
# [272]	validation_0-auc:0.88928
# [242]	validation_0-auc:0.89003
# [268]	validation_0-auc:0.88975
# [277]	validation_0-auc:0.88980
# [269]	validation_0-auc:0.88897
# [243]	validation_0-auc:0.89003
# [273]	validation_0-auc:0.88930
# [270]	validation_0-auc:0.88898
# [244]	validation_0-auc:0.89002
# [278]	validation_0-auc:0.88979
# [274]	validation_0-auc:0.88930
# [269]	validation_0-auc:0.88972
# [271]	validation_0-auc:0.88898
# [245]	validation_0-auc:0.89004
# [279]	validation_0-auc:0.88980
# [275]	validation_0-auc:0.88928
# [272]	validation_0-auc:0.88898
# [246]	validation_0-auc:0.89004
# [280]	validation_0-auc:0.88981
# [276]	validation_0-auc:0.88928
# [270]	validation_0-auc:0.88971
# [273]	validation_0-auc:0.88897
# [281]	validation_0-auc:0.88981
# [277]	validation_0-auc:0.88929
# [247]	validation_0-auc:0.89003
# [271]	validation_0-auc:0.88969
# [282]	validation_0-auc:0.88982
# [278]	validation_0-auc:0.88929
# [248]	validation_0-auc:0.89002
# [272]	validation_0-auc:0.88968
# [274]	validation_0-auc:0.88897
# [283]	validation_0-auc:0.88983
# [249]	validation_0-auc:0.89004
# [279]	validation_0-auc:0.88928
# [275]	validation_0-auc:0.88898
# [273]	validation_0-auc:0.88965
# [284]	validation_0-auc:0.88982
# [250]	validation_0-auc:0.89004
# [276]	validation_0-auc:0.88897
# [280]	validation_0-auc:0.88929
# [274]	validation_0-auc:0.88965
# [285]	validation_0-auc:0.88982
# [251]	validation_0-auc:0.89005
# [281]	validation_0-auc:0.88925
# [277]	validation_0-auc:0.88898
# [275]	validation_0-auc:0.88965
# [286]	validation_0-auc:0.88981
# [252]	validation_0-auc:0.89004
# [278]	validation_0-auc:0.88899
# [282]	validation_0-auc:0.88925
# [276]	validation_0-auc:0.88964
# [279]	validation_0-auc:0.88899
# [287]	validation_0-auc:0.88982
# [253]	validation_0-auc:0.89003
# [283]	validation_0-auc:0.88923
# [277]	validation_0-auc:0.88965
# [280]	validation_0-auc:0.88899
# [254]	validation_0-auc:0.89003
# [284]	validation_0-auc:0.88925
# [288]	validation_0-auc:0.88982
# [278]	validation_0-auc:0.88965
# [281]	validation_0-auc:0.88899
# [255]	validation_0-auc:0.89002
# [285]	validation_0-auc:0.88927
# [289]	validation_0-auc:0.88983
# [279]	validation_0-auc:0.88965
# [282]	validation_0-auc:0.88898
# [256]	validation_0-auc:0.89001
# [290]	validation_0-auc:0.88982
# [280]	validation_0-auc:0.88966
# [286]	validation_0-auc:0.88926
# [257]	validation_0-auc:0.89003
# [291]	validation_0-auc:0.88983
# [283]	validation_0-auc:0.88898
# [287]	validation_0-auc:0.88926
# [281]	validation_0-auc:0.88964
# [258]	validation_0-auc:0.89002
# [292]	validation_0-auc:0.88983
# [284]	validation_0-auc:0.88898
# [288]	validation_0-auc:0.88925
# [259]	validation_0-auc:0.89002
# [293]	validation_0-auc:0.88984
# [282]	validation_0-auc:0.88962
# [285]	validation_0-auc:0.88898
# [260]	validation_0-auc:0.88999
# [294]	validation_0-auc:0.88986
# [283]	validation_0-auc:0.88963
# [289]	validation_0-auc:0.88925
# [295]	validation_0-auc:0.88985
# [261]	validation_0-auc:0.88999
# [284]	validation_0-auc:0.88963
# [286]	validation_0-auc:0.88897
# [290]	validation_0-auc:0.88925
# [296]	validation_0-auc:0.88984
# [285]	validation_0-auc:0.88963
# [287]	validation_0-auc:0.88895
# [291]	validation_0-auc:0.88924
# [262]	validation_0-auc:0.88997
# [288]	validation_0-auc:0.88896
# [286]	validation_0-auc:0.88963
# [292]	validation_0-auc:0.88925
# [263]	validation_0-auc:0.88998
# [297]	validation_0-auc:0.88983
# [289]	validation_0-auc:0.88896
# [293]	validation_0-auc:0.88924
# [264]	validation_0-auc:0.88996
# [298]	validation_0-auc:0.88983
# [287]	validation_0-auc:0.88962
# [290]	validation_0-auc:0.88896
# [294]	validation_0-auc:0.88925
# [265]	validation_0-auc:0.88996
# [288]	validation_0-auc:0.88960
# [299]	validation_0-auc:0.88983
# [291]	validation_0-auc:0.88895
# [266]	validation_0-auc:0.88996
# [300]	validation_0-auc:0.88983
# [289]	validation_0-auc:0.88961
# [295]	validation_0-auc:0.88925
# [292]	validation_0-auc:0.88895
# [267]	validation_0-auc:0.88995
# [301]	validation_0-auc:0.88982
# [296]	validation_0-auc:0.88924
# [290]	validation_0-auc:0.88957
# [293]	validation_0-auc:0.88896
# [268]	validation_0-auc:0.88996
# [302]	validation_0-auc:0.88981
# [297]	validation_0-auc:0.88924
# [291]	validation_0-auc:0.88957
# [269]	validation_0-auc:0.88995
# [294]	validation_0-auc:0.88896
# [303]	validation_0-auc:0.88982
# [292]	validation_0-auc:0.88956
# [270]	validation_0-auc:0.88994
# [298]	validation_0-auc:0.88924
# [295]	validation_0-auc:0.88896
# [293]	validation_0-auc:0.88956
# [271]	validation_0-auc:0.88993
# [304]	validation_0-auc:0.88982
# [299]	validation_0-auc:0.88923
# [296]	validation_0-auc:0.88898
# [294]	validation_0-auc:0.88955
# [272]	validation_0-auc:0.88993
# [305]	validation_0-auc:0.88983
# [300]	validation_0-auc:0.88923
# [297]	validation_0-auc:0.88898
# [295]	validation_0-auc:0.88953
# [306]	validation_0-auc:0.88982
# [273]	validation_0-auc:0.88991
# [298]	validation_0-auc:0.88898
# [296]	validation_0-auc:0.88953
# [301]	validation_0-auc:0.88923
# [274]	validation_0-auc:0.88992
# [297]	validation_0-auc:0.88950
# [299]	validation_0-auc:0.88899
# [302]	validation_0-auc:0.88923
# [307]	validation_0-auc:0.88982
# [300]	validation_0-auc:0.88899
# [298]	validation_0-auc:0.88950
# [303]	validation_0-auc:0.88923
# [308]	validation_0-auc:0.88983
# [275]	validation_0-auc:0.88991
# [301]	validation_0-auc:0.88899
# [304]	validation_0-auc:0.88921
# [309]	validation_0-auc:0.88981
# [276]	validation_0-auc:0.88990
# [299]	validation_0-auc:0.88950
# [302]	validation_0-auc:0.88900
# [305]	validation_0-auc:0.88920
# [310]	validation_0-auc:0.88979
# [277]	validation_0-auc:0.88991
# [300]	validation_0-auc:0.88949
# [303]	validation_0-auc:0.88898
# [311]	validation_0-auc:0.88979
# [278]	validation_0-auc:0.88991
# [306]	validation_0-auc:0.88920
# [301]	validation_0-auc:0.88949
# [312]	validation_0-auc:0.88975
# [279]	validation_0-auc:0.88991
# [307]	validation_0-auc:0.88920
# [302]	validation_0-auc:0.88950
# [313]	validation_0-auc:0.88975
# [280]	validation_0-auc:0.88992
# [308]	validation_0-auc:0.88918
# [304]	validation_0-auc:0.88897
# [303]	validation_0-auc:0.88951
# [314]	validation_0-auc:0.88975
# [281]	validation_0-auc:0.88993
# [305]	validation_0-auc:0.88894
# [304]	validation_0-auc:0.88952
# [315]	validation_0-auc:0.88976
# [309]	validation_0-auc:0.88918
# [306]	validation_0-auc:0.88894
# [282]	validation_0-auc:0.88991
# [305]	validation_0-auc:0.88952
# [310]	validation_0-auc:0.88918
# [316]	validation_0-auc:0.88976
# [307]	validation_0-auc:0.88895
# [306]	validation_0-auc:0.88950
# [283]	validation_0-auc:0.88991
# [311]	validation_0-auc:0.88918
# [317]	validation_0-auc:0.88978
# [308]	validation_0-auc:0.88893
# [307]	validation_0-auc:0.88951
# [284]	validation_0-auc:0.88991
# [318]	validation_0-auc:0.88978
# [312]	validation_0-auc:0.88918
# [308]	validation_0-auc:0.88951
# [285]	validation_0-auc:0.88992
# [309]	validation_0-auc:0.88892
# [319]	validation_0-auc:0.88976
# [313]	validation_0-auc:0.88916
# [310]	validation_0-auc:0.88894
# [286]	validation_0-auc:0.88991
# [309]	validation_0-auc:0.88950
# [314]	validation_0-auc:0.88915
# [311]	validation_0-auc:0.88895
# [287]	validation_0-auc:0.88991
# [310]	validation_0-auc:0.88947
# [315]	validation_0-auc:0.88915
# [320]	validation_0-auc:0.88975
# [312]	validation_0-auc:0.88894
# [288]	validation_0-auc:0.88991
# [311]	validation_0-auc:0.88947
# [316]	validation_0-auc:0.88914
# [313]	validation_0-auc:0.88893
# [289]	validation_0-auc:0.88991
# [312]	validation_0-auc:0.88948
# [317]	validation_0-auc:0.88914
# [321]	validation_0-auc:0.88975
# [290]	validation_0-auc:0.88991
# [313]	validation_0-auc:0.88947
# [318]	validation_0-auc:0.88912
# [314]	validation_0-auc:0.88893
# [322]	validation_0-auc:0.88974
# [291]	validation_0-auc:0.88991
# [314]	validation_0-auc:0.88948
# ...
# [382]	validation_0-auc:0.88872
# [359]	validation_0-auc:0.88965
# [382]	validation_0-auc:0.88915
# [386]	validation_0-auc:0.88881
# [383]	validation_0-auc:0.88871
# [388]	validation_0-auc:0.88934
# [387]	validation_0-auc:0.88882
# [383]	validation_0-auc:0.88914
# [384]	validation_0-auc:0.88870
# [360]	validation_0-auc:0.88966
# [388]	validation_0-auc:0.88881
# [384]	validation_0-auc:0.88915
# [389]	validation_0-auc:0.88934
# [385]	validation_0-auc:0.88869
# [361]	validation_0-auc:0.88967
# [389]	validation_0-auc:0.88881
# [390]	validation_0-auc:0.88938
# [385]	validation_0-auc:0.88914
# [386]	validation_0-auc:0.88868
# [362]	validation_0-auc:0.88968
# [391]	validation_0-auc:0.88936
# [390]	validation_0-auc:0.88881
# [387]	validation_0-auc:0.88867
# [386]	validation_0-auc:0.88914
# [363]	validation_0-auc:0.88966
# [392]	validation_0-auc:0.88934
# [388]	validation_0-auc:0.88868
# [391]	validation_0-auc:0.88881
# [364]	validation_0-auc:0.88965
# [387]	validation_0-auc:0.88913
# [393]	validation_0-auc:0.88932
# [365]	validation_0-auc:0.88964
# [389]	validation_0-auc:0.88868
# [392]	validation_0-auc:0.88882
# [388]	validation_0-auc:0.88912
# [366]	validation_0-auc:0.88965
# [390]	validation_0-auc:0.88870
# [394]	validation_0-auc:0.88933
# [393]	validation_0-auc:0.88881
# [367]	validation_0-auc:0.88965
# [391]	validation_0-auc:0.88870
# [389]	validation_0-auc:0.88912
# [394]	validation_0-auc:0.88882
# [395]	validation_0-auc:0.88934
# [392]	validation_0-auc:0.88870
# [368]	validation_0-auc:0.88963
# [390]	validation_0-auc:0.88912
# [396]	validation_0-auc:0.88933
# [395]	validation_0-auc:0.88883
# [393]	validation_0-auc:0.88870
# [391]	validation_0-auc:0.88910
# [397]	validation_0-auc:0.88932[369]	validation_0-auc:0.88963
#
# [396]	validation_0-auc:0.88881
# [394]	validation_0-auc:0.88872
# [370]	validation_0-auc:0.88964
# [392]	validation_0-auc:0.88911
# [398]	validation_0-auc:0.88928
# [395]	validation_0-auc:0.88871
# [397]	validation_0-auc:0.88880
# [393]	validation_0-auc:0.88910
# [399]	validation_0-auc:0.88928
# [371]	validation_0-auc:0.88964
# [396]	validation_0-auc:0.88870
# [398]	validation_0-auc:0.88878
# [394]	validation_0-auc:0.88911
# [397]	validation_0-auc:0.88867
# [399]	validation_0-auc:0.88878
# [395]	validation_0-auc:0.88911
# [372]	validation_0-auc:0.88963
# [398]	validation_0-auc:0.88866
# [373]	validation_0-auc:0.88962
# [396]	validation_0-auc:0.88911
# [399]	validation_0-auc:0.88865
# [397]	validation_0-auc:0.88913
# [374]	validation_0-auc:0.88964
# [398]	validation_0-auc:0.88914
# [375]	validation_0-auc:0.88963
# [399]	validation_0-auc:0.88915
# [376]	validation_0-auc:0.88964
# [377]	validation_0-auc:0.88964
# [378]	validation_0-auc:0.88964
# [379]	validation_0-auc:0.88964
# [CV] END ......................max_depth=4, n_estimators=400; total time=   4.7s
# [380]	validation_0-auc:0.88963
# [381]	validation_0-auc:0.88964
# [CV] END ......................max_depth=4, n_estimators=400; total time=   4.8s
# [CV] END ......................max_depth=4, n_estimators=400; total time=   4.8s
# [382]	validation_0-auc:0.88963
# [383]	validation_0-auc:0.88962
# [384]	validation_0-auc:0.88960
# [CV] END ......................max_depth=4, n_estimators=400; total time=   4.8s
# [385]	validation_0-auc:0.88960
# [386]	validation_0-auc:0.88959
# [387]	validation_0-auc:0.88958
# [388]	validation_0-auc:0.88958
# [389]	validation_0-auc:0.88958
# [390]	validation_0-auc:0.88957
# [391]	validation_0-auc:0.88956
# [392]	validation_0-auc:0.88957
# [393]	validation_0-auc:0.88956
# [394]	validation_0-auc:0.88955
# [395]	validation_0-auc:0.88955
# [396]	validation_0-auc:0.88954
# [397]	validation_0-auc:0.88952
# [398]	validation_0-auc:0.88954
# [399]	validation_0-auc:0.88954
# [CV] END ......................max_depth=4, n_estimators=400; total time=   5.0s
# [0]	validation_0-auc:0.86106
# [1]	validation_0-auc:0.85877
# [2]	validation_0-auc:0.86886
# [3]	validation_0-auc:0.86949
# [4]	validation_0-auc:0.87315
# [5]	validation_0-auc:0.87189
# [6]	validation_0-auc:0.87366
# [7]	validation_0-auc:0.87841
# [8]	validation_0-auc:0.88045
# [9]	validation_0-auc:0.88154
# [10]	validation_0-auc:0.88213
# [11]	validation_0-auc:0.88202
# [12]	validation_0-auc:0.88212
# [13]	validation_0-auc:0.88193
# [14]	validation_0-auc:0.88223
# [15]	validation_0-auc:0.88227
# [16]	validation_0-auc:0.88258
# [17]	validation_0-auc:0.88290
# [18]	validation_0-auc:0.88289
# [19]	validation_0-auc:0.88371
# [20]	validation_0-auc:0.88423
# [21]	validation_0-auc:0.88443
# [22]	validation_0-auc:0.88488
# [23]	validation_0-auc:0.88523
# [24]	validation_0-auc:0.88561
# [25]	validation_0-auc:0.88586
# [26]	validation_0-auc:0.88593
# [27]	validation_0-auc:0.88593
# [28]	validation_0-auc:0.88604
# [29]	validation_0-auc:0.88643
# [30]	validation_0-auc:0.88650
# [31]	validation_0-auc:0.88670
# [32]	validation_0-auc:0.88691
# [33]	validation_0-auc:0.88701
# [34]	validation_0-auc:0.88726
# [35]	validation_0-auc:0.88734
# [36]	validation_0-auc:0.88744
# [37]	validation_0-auc:0.88752
# [38]	validation_0-auc:0.88757
# [39]	validation_0-auc:0.88766
# [40]	validation_0-auc:0.88779
# [41]	validation_0-auc:0.88791
# [42]	validation_0-auc:0.88799
# [43]	validation_0-auc:0.88804
# [44]	validation_0-auc:0.88804
# [45]	validation_0-auc:0.88820
# [46]	validation_0-auc:0.88824
# [47]	validation_0-auc:0.88832
# [48]	validation_0-auc:0.88835
# [49]	validation_0-auc:0.88841
# [50]	validation_0-auc:0.88843
# [51]	validation_0-auc:0.88850
# [52]	validation_0-auc:0.88855
# [53]	validation_0-auc:0.88856
# [54]	validation_0-auc:0.88862
# [55]	validation_0-auc:0.88865
# [56]	validation_0-auc:0.88871
# [57]	validation_0-auc:0.88875
# [58]	validation_0-auc:0.88878
# [59]	validation_0-auc:0.88883
# [60]	validation_0-auc:0.88888
# [61]	validation_0-auc:0.88892
# [62]	validation_0-auc:0.88897
# [63]	validation_0-auc:0.88896
# [64]	validation_0-auc:0.88899
# [65]	validation_0-auc:0.88905
# [66]	validation_0-auc:0.88910
# [67]	validation_0-auc:0.88911
# [68]	validation_0-auc:0.88913
# [69]	validation_0-auc:0.88921
# [70]	validation_0-auc:0.88924
# [71]	validation_0-auc:0.88926
# [72]	validation_0-auc:0.88928
# [73]	validation_0-auc:0.88932
# [74]	validation_0-auc:0.88934
# [75]	validation_0-auc:0.88935
# [76]	validation_0-auc:0.88936
# [77]	validation_0-auc:0.88938
# [78]	validation_0-auc:0.88940
# [79]	validation_0-auc:0.88940
# [80]	validation_0-auc:0.88944
# [81]	validation_0-auc:0.88946
# [82]	validation_0-auc:0.88947
# [83]	validation_0-auc:0.88947
# [84]	validation_0-auc:0.88948
# [85]	validation_0-auc:0.88952
# [86]	validation_0-auc:0.88953
# [87]	validation_0-auc:0.88954
# [88]	validation_0-auc:0.88956
# [89]	validation_0-auc:0.88954
# [90]	validation_0-auc:0.88956
# [91]	validation_0-auc:0.88958
# [92]	validation_0-auc:0.88958
# [93]	validation_0-auc:0.88959
# [94]	validation_0-auc:0.88959
# [95]	validation_0-auc:0.88959
# [96]	validation_0-auc:0.88960
# [97]	validation_0-auc:0.88960
# [98]	validation_0-auc:0.88960
# [99]	validation_0-auc:0.88961
# [100]	validation_0-auc:0.88963
# [101]	validation_0-auc:0.88963
# [102]	validation_0-auc:0.88962
# [103]	validation_0-auc:0.88964
# [104]	validation_0-auc:0.88967
# [105]	validation_0-auc:0.88970
# [106]	validation_0-auc:0.88973
# [107]	validation_0-auc:0.88975
# [108]	validation_0-auc:0.88976
# [109]	validation_0-auc:0.88977
# [110]	validation_0-auc:0.88978
# [111]	validation_0-auc:0.88980
# [112]	validation_0-auc:0.88980
# [113]	validation_0-auc:0.88976
# [114]	validation_0-auc:0.88976
# [115]	validation_0-auc:0.88977
# [116]	validation_0-auc:0.88977
# [117]	validation_0-auc:0.88978
# [118]	validation_0-auc:0.88977
# [119]	validation_0-auc:0.88977
# [120]	validation_0-auc:0.88976
# [121]	validation_0-auc:0.88975
# [122]	validation_0-auc:0.88976
# [123]	validation_0-auc:0.88973
# [124]	validation_0-auc:0.88972
# [125]	validation_0-auc:0.88973
# [126]	validation_0-auc:0.88976
# [127]	validation_0-auc:0.88979
# [128]	validation_0-auc:0.88980
# [129]	validation_0-auc:0.88980
# [130]	validation_0-auc:0.88980
# [131]	validation_0-auc:0.88983
# [132]	validation_0-auc:0.88982
# [133]	validation_0-auc:0.88982
# [134]	validation_0-auc:0.88983
# [135]	validation_0-auc:0.88983
# [136]	validation_0-auc:0.88985
# [137]	validation_0-auc:0.88987
# [138]	validation_0-auc:0.88986
# [139]	validation_0-auc:0.88984
# [140]	validation_0-auc:0.88984
# [141]	validation_0-auc:0.88986
# [142]	validation_0-auc:0.88985
# [143]	validation_0-auc:0.88987
# [144]	validation_0-auc:0.88988
# [145]	validation_0-auc:0.88988
# [146]	validation_0-auc:0.88985
# [147]	validation_0-auc:0.88984
# [148]	validation_0-auc:0.88985
# [149]	validation_0-auc:0.88985
# [150]	validation_0-auc:0.88986
# [151]	validation_0-auc:0.88986
# [152]	validation_0-auc:0.88987
# [153]	validation_0-auc:0.88987
# [154]	validation_0-auc:0.88989
# [155]	validation_0-auc:0.88988
# [156]	validation_0-auc:0.88987
# [157]	validation_0-auc:0.88987
# [158]	validation_0-auc:0.88988
# [159]	validation_0-auc:0.88988
# [160]	validation_0-auc:0.88987
# [161]	validation_0-auc:0.88990
# [162]	validation_0-auc:0.88992
# [163]	validation_0-auc:0.88993
# [164]	validation_0-auc:0.88992
# [165]	validation_0-auc:0.88994
# [166]	validation_0-auc:0.88995
# [167]	validation_0-auc:0.88995
# [168]	validation_0-auc:0.88995
# [169]	validation_0-auc:0.88995
# [170]	validation_0-auc:0.88994
# [171]	validation_0-auc:0.88996
# [172]	validation_0-auc:0.88997
# [173]	validation_0-auc:0.88995
# [174]	validation_0-auc:0.88995
# [175]	validation_0-auc:0.88998
# [176]	validation_0-auc:0.88996
# [177]	validation_0-auc:0.88997
# [178]	validation_0-auc:0.88998
# [179]	validation_0-auc:0.88999
# [180]	validation_0-auc:0.88998
# [181]	validation_0-auc:0.88999
# [182]	validation_0-auc:0.89001
# [183]	validation_0-auc:0.89002
# [184]	validation_0-auc:0.89004
# [185]	validation_0-auc:0.89003
# [186]	validation_0-auc:0.89004
# [187]	validation_0-auc:0.89005
# [188]	validation_0-auc:0.89005
# [189]	validation_0-auc:0.89006
# [190]	validation_0-auc:0.89007
# [191]	validation_0-auc:0.89008
# [192]	validation_0-auc:0.89009
# [193]	validation_0-auc:0.89010
# [194]	validation_0-auc:0.89008
# [195]	validation_0-auc:0.89011
# [196]	validation_0-auc:0.89012
# [197]	validation_0-auc:0.89012
# [198]	validation_0-auc:0.89011
# [199]	validation_0-auc:0.89010
# [200]	validation_0-auc:0.89010
# [201]	validation_0-auc:0.89009
# [202]	validation_0-auc:0.89009
# [203]	validation_0-auc:0.89009
# [204]	validation_0-auc:0.89009
# [205]	validation_0-auc:0.89008
# [206]	validation_0-auc:0.89006
# [207]	validation_0-auc:0.89007
# [208]	validation_0-auc:0.89004
# [209]	validation_0-auc:0.89003
# [210]	validation_0-auc:0.89002
# [211]	validation_0-auc:0.89003
# [212]	validation_0-auc:0.89004
# [213]	validation_0-auc:0.89003
# [214]	validation_0-auc:0.89005
# [215]	validation_0-auc:0.89004
# [216]	validation_0-auc:0.89001
# [217]	validation_0-auc:0.89002
# [218]	validation_0-auc:0.89001
# [219]	validation_0-auc:0.89002
# [220]	validation_0-auc:0.89001
# [221]	validation_0-auc:0.89000
# [222]	validation_0-auc:0.88999
# [223]	validation_0-auc:0.88998
# [224]	validation_0-auc:0.88999
# [225]	validation_0-auc:0.88999
# [226]	validation_0-auc:0.88999
# [227]	validation_0-auc:0.89001
# [228]	validation_0-auc:0.89001
# [229]	validation_0-auc:0.88999
# [230]	validation_0-auc:0.89000
# [231]	validation_0-auc:0.88998
# [232]	validation_0-auc:0.88999
# [233]	validation_0-auc:0.88999
# [234]	validation_0-auc:0.88998
# [235]	validation_0-auc:0.88998
# [236]	validation_0-auc:0.88997
# [237]	validation_0-auc:0.88996
# [238]	validation_0-auc:0.88997
# [239]	validation_0-auc:0.88998
# [240]	validation_0-auc:0.89001
# [241]	validation_0-auc:0.88999
# [242]	validation_0-auc:0.89000
# [243]	validation_0-auc:0.89001
# [244]	validation_0-auc:0.89001
# [245]	validation_0-auc:0.89001
# [246]	validation_0-auc:0.89002
# [247]	validation_0-auc:0.89003
# [248]	validation_0-auc:0.89003
# [249]	validation_0-auc:0.89005
# [250]	validation_0-auc:0.89002
# [251]	validation_0-auc:0.89002
# [252]	validation_0-auc:0.89001
# [253]	validation_0-auc:0.88999
# [254]	validation_0-auc:0.88997
# [255]	validation_0-auc:0.88999
# [256]	validation_0-auc:0.88999
# [257]	validation_0-auc:0.88998
# [258]	validation_0-auc:0.88998
# [259]	validation_0-auc:0.88996
# [260]	validation_0-auc:0.88994
# [261]	validation_0-auc:0.88994
# [262]	validation_0-auc:0.88994
# [263]	validation_0-auc:0.88994
# [264]	validation_0-auc:0.88994
# [265]	validation_0-auc:0.88994
# [266]	validation_0-auc:0.88994
# [267]	validation_0-auc:0.88994
# [268]	validation_0-auc:0.88993
# [269]	validation_0-auc:0.88991
# [270]	validation_0-auc:0.88991
# [271]	validation_0-auc:0.88989
# [272]	validation_0-auc:0.88988
# [273]	validation_0-auc:0.88987
# [274]	validation_0-auc:0.88987
# [275]	validation_0-auc:0.88988
# [276]	validation_0-auc:0.88989
# [277]	validation_0-auc:0.88985
# [278]	validation_0-auc:0.88985
# [279]	validation_0-auc:0.88985
# [280]	validation_0-auc:0.88985
# [281]	validation_0-auc:0.88984
# [282]	validation_0-auc:0.88985
# [283]	validation_0-auc:0.88982
# [284]	validation_0-auc:0.88982
# [285]	validation_0-auc:0.88981
# [286]	validation_0-auc:0.88980
# [287]	validation_0-auc:0.88979
# [288]	validation_0-auc:0.88977
# [289]	validation_0-auc:0.88979
# [290]	validation_0-auc:0.88979
# [291]	validation_0-auc:0.88977
# [292]	validation_0-auc:0.88977
# [293]	validation_0-auc:0.88976
# [294]	validation_0-auc:0.88976
# [295]	validation_0-auc:0.88975
# [296]	validation_0-auc:0.88975
# [297]	validation_0-auc:0.88974
# [298]	validation_0-auc:0.88974
# [299]	validation_0-auc:0.88974
# [300]	validation_0-auc:0.88974
# [301]	validation_0-auc:0.88974
# [302]	validation_0-auc:0.88975
# [303]	validation_0-auc:0.88976
# [304]	validation_0-auc:0.88976
# [305]	validation_0-auc:0.88976
# [306]	validation_0-auc:0.88976
# [307]	validation_0-auc:0.88974
# [308]	validation_0-auc:0.88974
# [309]	validation_0-auc:0.88975
# [310]	validation_0-auc:0.88974
# [311]	validation_0-auc:0.88973
# [312]	validation_0-auc:0.88973
# [313]	validation_0-auc:0.88974
# [314]	validation_0-auc:0.88974
# [315]	validation_0-auc:0.88973
# [316]	validation_0-auc:0.88974
# [317]	validation_0-auc:0.88973
# [318]	validation_0-auc:0.88972
# [319]	validation_0-auc:0.88973
# [320]	validation_0-auc:0.88973
# [321]	validation_0-auc:0.88971
# [322]	validation_0-auc:0.88969
# [323]	validation_0-auc:0.88971
# [324]	validation_0-auc:0.88972
# [325]	validation_0-auc:0.88973
# [326]	validation_0-auc:0.88974
# [327]	validation_0-auc:0.88974
# [328]	validation_0-auc:0.88976
# [329]	validation_0-auc:0.88975
# [330]	validation_0-auc:0.88975
# [331]	validation_0-auc:0.88974
# [332]	validation_0-auc:0.88975
# [333]	validation_0-auc:0.88977
# [334]	validation_0-auc:0.88974
# [335]	validation_0-auc:0.88976
# [336]	validation_0-auc:0.88975
# [337]	validation_0-auc:0.88973
# [338]	validation_0-auc:0.88976
# [339]	validation_0-auc:0.88974
# [340]	validation_0-auc:0.88972
# [341]	validation_0-auc:0.88972
# [342]	validation_0-auc:0.88972
# [343]	validation_0-auc:0.88969
# [344]	validation_0-auc:0.88969
# [345]	validation_0-auc:0.88967
# [346]	validation_0-auc:0.88967
# [347]	validation_0-auc:0.88968
# [348]	validation_0-auc:0.88969
# [349]	validation_0-auc:0.88970
# [350]	validation_0-auc:0.88971
# [351]	validation_0-auc:0.88971
# [352]	validation_0-auc:0.88969
# [353]	validation_0-auc:0.88969
# [354]	validation_0-auc:0.88966
# [355]	validation_0-auc:0.88964
# [356]	validation_0-auc:0.88964
# [357]	validation_0-auc:0.88964
# [358]	validation_0-auc:0.88963
# [359]	validation_0-auc:0.88964
# [360]	validation_0-auc:0.88963
# [361]	validation_0-auc:0.88961
# [362]	validation_0-auc:0.88960
# [363]	validation_0-auc:0.88958
# [364]	validation_0-auc:0.88957
# [365]	validation_0-auc:0.88957
# [366]	validation_0-auc:0.88957
# [367]	validation_0-auc:0.88956
# [368]	validation_0-auc:0.88954
# [369]	validation_0-auc:0.88953
# [370]	validation_0-auc:0.88954
# [371]	validation_0-auc:0.88956
# [372]	validation_0-auc:0.88955
# [373]	validation_0-auc:0.88953
# [374]	validation_0-auc:0.88954
# [375]	validation_0-auc:0.88955
# [376]	validation_0-auc:0.88956
# [377]	validation_0-auc:0.88957
# [378]	validation_0-auc:0.88958
# [379]	validation_0-auc:0.88957
# [380]	validation_0-auc:0.88958
# [381]	validation_0-auc:0.88958
# [382]	validation_0-auc:0.88957
# [383]	validation_0-auc:0.88957
# [384]	validation_0-auc:0.88959
# [385]	validation_0-auc:0.88958
# [386]	validation_0-auc:0.88957
# [387]	validation_0-auc:0.88958
# [388]	validation_0-auc:0.88956
# [389]	validation_0-auc:0.88955
# [390]	validation_0-auc:0.88955
# [391]	validation_0-auc:0.88953
# [392]	validation_0-auc:0.88953
# [393]	validation_0-auc:0.88950
# [394]	validation_0-auc:0.88950
# [395]	validation_0-auc:0.88951
# [396]	validation_0-auc:0.88953
# [397]	validation_0-auc:0.88950
# [398]	validation_0-auc:0.88950
# [399]	validation_0-auc:0.88949
# Best parameters found:  {'max_depth': 4, 'n_estimators': 400}
# Best score found:  0.8890096979339273

# %% [markdown]
# #### Making Predictions

# %%
y_pred_xgboost = xgb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87     26023
#            1       0.52      0.54      0.53      6984
#
#     accuracy                           0.80     33007
#    macro avg       0.70      0.70      0.70     33007
# weighted avg       0.80      0.80      0.80     33007

# %% [markdown]
# #### ROC Curve

# %% [markdown]
# baseline: 0.8886
#
# isSenior: 0.8884
#
# isSenior and activeByCard: 0.8848

# %%
y_pred_prob = xgb_model.predict_proba(X_test)[:, 1]
# Calculate ROC curve data
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate the Area Under the ROC Curve (AUC)
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
y_pred_prob
# Out:
# array([0.28996015, 0.885929  , 0.07586987, ..., 0.15682401, 0.03543866,
#        0.15256575], dtype=float32)

# %% [markdown]
# #### XGBoost Feature Importances

# %% [markdown]
# The initial model emphasizes **Age** as the most important feature. The age of an individual must be a crucial role. This is followed by similarly-important **Credit Scire**, **Balance**, and **Estimated Salary**.
#
# The model heavily weighs these variables as top predictors.

# %%
plt.figure(figsize=(10, 8))
plot_importance(xgb_model, height=0.5)
plt.show()

# %% [markdown]
# ## 👀 Observations

# %% [markdown]
# Having **Tenure** as a numerical variable sees notable improvements in performance - accuracy moves from 79 to 80

# %% [markdown]
# ## ✅ Submission

# %%
df_final = pd.read_csv('./test.csv')
df_final.shape
# Out:
# (110023, 13)

# %%
df_final_clean = df_final.copy()

# %%
df_final_clean['isSenior'] = df_final_clean['Age'].apply(lambda x: 1 if x >=60 else 0)
df_final_clean['activeByCard'] = df_final_clean['HasCrCard'] * df_final_clean['IsActiveMember']
df_final_clean['productsPerTenure'] = df_final_clean['Tenure'] / df_final_clean['NumOfProducts']
df_final_clean['ageCat'] = np.round(df_final_clean.Age/20).astype('int').astype('category')

# %%
df_final_clean = df_final_clean.drop(remove, axis=1)

# %%
df_final_clean[numerical_variables] = scaler.fit_transform(df_final_clean[numerical_variables])

# %%
df_final_clean, _ = encode(df_final_clean, categorical_variables)

# %%
# preds = classifier.predict(df_final_clean[features])
preds = xgb_model.predict_proba(df_final_clean[features])
# y_pred_prob = xgb_model.predict_proba(X_test)[:, 1]

preds[:10]
# Out:
# array([[0.917187  , 0.08281304],
#        [0.08748275, 0.91251725],
#        [0.87776923, 0.12223075],
#        [0.44827318, 0.5517268 ],
#        [0.33335686, 0.66664314],
#        [0.8480131 , 0.1519869 ],
#        [0.8449    , 0.15510002],
#        [0.75434095, 0.24565905],
#        [0.1466605 , 0.8533395 ],
#        [0.94808376, 0.05191622]], dtype=float32)

# %%
df_idc = pd.read_csv('./sample_submission.csv')
df_idc.head()
# Out:
#        id  Exited
# 0  165034     0.5
# 1  165035     0.5
# 2  165036     0.5
# 3  165037     0.5
# 4  165038     0.5

# %%
submission_df = pd.DataFrame()
submission_df['id'] = df_final['id']
submission_df['Exited'] = preds[:, 1]
submission_df.head()
# Out:
#        id    Exited
# 0  165034  0.082813
# 1  165035  0.912517
# 2  165036  0.122231
# 3  165037  0.551727
# 4  165038  0.666643

# %%
submission_df.to_csv('./submission.csv', index=False)
